# %%
import pandas as pd
from pandas import DataFrame
from datetime import datetime
from typing import List, Dict, Tuple, Optional
import pickle

import pickle
from beanie import PydanticObjectId
from mongo_backend import (init_db, bulk_insert, construct_formulation_list_from_df, insert_compounds, 
                         construct_MLformulation_list_from_df, insert_preparation_ML_formulations)

# %%
prep_df = pd.read_csv("datasets\\preparation_formulation.csv")
prep_list = construct_formulation_list_from_df(prep_df, "volume_percent")

# %%
prep_list
# Out:
# [{'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiClO4', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FEC',
#     'quantity': 0.05,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LICLO4-PC + 5% FEC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 EC-DMC (1:1 V) 2% VC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiBF4', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIBF4 EC-DMC (1:1 V) 2% VC'},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFPFB', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1M LITFPFB PC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.2462065589818893,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 0.7537934410181106,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 EC-EMC (3:7 WT) 2% WT VC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LITFSI EC-DMC (1:1 V) 2% VC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.7, 'quantity_type': 'volume_percent'}],
#   'description': '1M LIPF6 EC-DMC (3:7 V/V)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.2667578659370725,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.7332421340629275,
#     'quantity_type': 'volume_percent'}],
#   'description': '1M LIPF6 EC-DEC (1:2 W/W)'},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiAsF6', 'quantity': 1.5, 'quantity_type': 'moles'}],
#   'description': '1.5 M LIASF6-PC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiBETI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'VC', 'quantity': 0.02, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIBETI EC-DMC (1:1 V) 2% VC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.333,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 0.667,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 EC-DMC (1:2 VOL)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.2404438964241677,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.7595561035758323,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 EC-DEC (3:7 WT)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6-EC/DEC (1:1 VOL.)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.4325021496130696,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.6, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 0.5674978503869303,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiBOB', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (5:5 WT)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.4248366013071895,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.5751633986928105,
#     'quantity_type': 'volume_percent'}],
#   'description': '1M LIPF6 EC-DEC (1:1 W/W)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.333,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 0.667,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 EC-DMC (1:2 VOL) 2% TTFEB'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.6400654426467914,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.6, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 0.3599345573532084,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiBOB', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (7:3 WT)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.8727588201272412,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.6, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 0.1272411798727588,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiBOB', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (9:1 WT)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EC', 'quantity': 0.45, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'DEC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LITFSI EC-DMC (1:1 V) 5WT% FEC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 3.57, 'quantity_type': 'moles'}],
#   'description': '3.57 M LITFSI DME'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1M LIFSI EC/DEC (V 1:1)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiDFP', 'quantity': 0.1, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.7, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.1M LIDFP 0.4M LITFSI EC-DMC (3:7 V/V)'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.84, 'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 2.7, 'quantity_type': 'moles'}],
#   'description': '0.84 M LITFSI 2.7M LIDFP DME'},
#  {'formulation': [{'compound_id': 'Tetraglyme',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI IN TETRAGLYME'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0025,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.25WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.11, 'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 3.9, 'quantity_type': 'moles'}],
#   'description': '0.11 M LITFSI 3.9 M LIDFP DME'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EC', 'quantity': 0.45, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'RbNO3', 'quantity': 0.05, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL) 0.05 M RBNO3 0.05M 18-CROWN-6'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiDFP', 'quantity': 0.1, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.7, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.1M LIDFP 0.4M LIFSI EC-DMC (3:7 V/V)'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 2.0, 'quantity_type': 'moles'},
#    {'compound_id': 'LiDFOB', 'quantity': 2.0, 'quantity_type': 'moles'}],
#   'description': '2M LITFSI 2M LIDFOB DME'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.02,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 2WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 2.2, 'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 0.8, 'quantity_type': 'moles'}],
#   'description': '2.2 M LITFSI 0.8 M LIDFP DME'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'FEC',
#     'quantity': 0.05,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6-EC/DEC (1:1 VOL.) + 5 VOL% FEC'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiNO3', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'Li2S5', 'quantity': 0.15, 'quantity_type': 'moles'}],
#   'description': '0.02M LI2S5 0.15M LINO3 1M LITFSI DOL-DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DEG-FTriEG',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI IN DEG-FTRIEG'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.2404438964241677,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiDFOB', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.7595561035758323,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIDFOB EC-DEC (3:7 WT)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.278628829745826,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 0.6259312142878466,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'DMC',
#     'quantity': 0.0954399559663273,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-EMC-DMC (34.6:57.2:8.2 WT)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.4248366013071895,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.5751633986928105,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiDFP', 'quantity': 0.15, 'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 IN EC/DEC + 0.15M LIDFP'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0175,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.75WT% 12-CROWN-4'},
#  {'formulation': [], 'description': 'LIFSI-1.4DME-3TFEB'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.015,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.5WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 3.0, 'quantity_type': 'moles'}],
#   'description': '3M LITFSI DME'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.005,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.5WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'THF',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI THF'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 6.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '6 M LIPF6 EC-DEC (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 0.5, 'quantity_type': 'moles'},
#    {'compound_id': 'LiPO2F2', 'quantity': 0.5, 'quantity_type': 'moles'}],
#   'description': '0.5 M LIFSI+0.5 M LIPO2F2/DME'},
#  {'formulation': [{'compound_id': 'SL',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 3.25, 'quantity_type': 'moles'}],
#   'description': '3.25M LITFSI SL'},
#  {'formulation': [{'compound_id': 'EA',
#     'quantity': 0.2,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 5.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DCM', 'quantity': 0.8, 'quantity_type': 'volume_percent'}],
#   'description': '5M LITFSI 1-4 (EA-DCM VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0125,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.25WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 2.0, 'quantity_type': 'moles'}],
#   'description': '2 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.2857,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'BTFEC',
#     'quantity': 0.7143,
#     'quantity_type': 'volume_percent'}],
#   'description': 'LIFSI-1.2DME-3BTFEC'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0075,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.75WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.4013997529847674,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.5986002470152326,
#     'quantity_type': 'volume_percent'}],
#   'description': '1M LIPF6 FEC-DEC (1:1 W/W)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'Li2S5', 'quantity': 0.1, 'quantity_type': 'moles'},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.7772999999999999,
#     'quantity_type': 'moles'}],
#   'description': '0.1 M LI2S5 + 5% LINO3 IN 1 M LITFSI IN DOL/DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFNFSI', 'quantity': 3.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '3 M LIFNFSI IN DOL/DME'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.5, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiNO3', 'quantity': 0.5, 'quantity_type': 'moles'}],
#   'description': '0.5 M LITFSI 0.5 M LINO3 DOL-DME (1:1 V)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiClO4', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'ES', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LICLO4 EC-ES (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EC', 'quantity': 0.45, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'RbNO3', 'quantity': 0.1, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL) 0.1 M RBNO3 0.1M 18-CROWN-6'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 3.0, 'quantity_type': 'moles'}],
#   'description': '3 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.01,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.1WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1M LIFSI DME'},
#  {'formulation': [{'compound_id': 'TEP',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 3.2, 'quantity_type': 'moles'}],
#   'description': '3.2M LIFSI TEP'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LITFSI IN DOL/DME WITH 5WT% TMS-FNFSI'},
#  {'formulation': [], 'description': 'LIFSI SL (1:3 MOLAR)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 4.0, 'quantity_type': 'moles'}],
#   'description': '4 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.3333,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'FEC', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 0.6667,
#     'quantity_type': 'volume_percent'}],
#   'description': '1M LIFSI FEC-DEC (1:2 BY VOLUME)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'ETFEC',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIFSI/EC-ETFEC (3:7 VOL)'},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 5.0, 'quantity_type': 'moles'}],
#   'description': '5 M LIFSI PC'},
#  {'formulation': [{'compound_id': '1,4-Dioxolane',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI 1,4-DIOXOLANE'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.50944669365722,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'TFEC',
#     'quantity': 0.49055330634278,
#     'quantity_type': 'volume_percent'}],
#   'description': '1M LIPF6 FEC-TFEC (1:1 W/W)'},
#  {'formulation': [{'compound_id': 'MTFP',
#     'quantity': 0.9,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FEC', 'quantity': 0.1, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 MTFP-FEC (9:1 VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 5.0, 'quantity_type': 'moles'}],
#   'description': '5 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 6.0, 'quantity_type': 'moles'}],
#   'description': '6 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'DMB',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1M LIFSI DMB'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.15,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 0.3, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.15, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiNO3', 'quantity': 0.35, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.7, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 EC-DMC (1:1 V), 0.5 M LINO3 TEGDME, 70%'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 7.0, 'quantity_type': 'moles'}],
#   'description': '7 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'DME', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DOL', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1M LITFSI DME-DOL (1:1) 3% LINO3'},
#  {'formulation': [{'compound_id': 'FSA',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI FSA'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 4.6, 'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 2.3, 'quantity_type': 'moles'}],
#   'description': '4.6 M LIFSI 2.3 M LITFSI DME'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.25,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 0.5, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.25, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiNO3', 'quantity': 0.25, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 EC-DMC (1:1 V), 0.5 M LINO3 TEGDME, 50%'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.3863731762282948,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 0.531554576832353,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'TMSB', 'quantity': 0.01, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 0.0820722469393522,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-EMC-DMC (34.6:57.2:8.2 WT) 1WT% TMSB'},
#  {'formulation': [{'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles'},
#    {'compound_id': 'SL', 'quantity': 2.5, 'quantity_type': 'moles'}],
#   'description': 'LIFSI SL (1:2.5 MOLAR)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FEMC', 'quantity': 0.2, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'D2', 'quantity': 0.7, 'quantity_type': 'volume_percent'}],
#   'description': '1M LIFSI FEC-FEMC-D2 (234:280:793 BY MOL)'},
#  {'formulation': [], 'description': '1 LIFSI - 3 TMS'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 0.2422754453570001,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7577245546429999,
#     'quantity_type': 'volume_percent'}],
#   'description': '1.2M LIFSI DMC-BTFE (1:2 MOL)'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 4.6, 'quantity_type': 'moles'}],
#   'description': '4.6 M LIFSI DME'},
#  {'formulation': [{'compound_id': 'MTHF',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI METHF'},
#  {'formulation': [], 'description': 'LIFSI DMC (1:1.5 MOL)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.4, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiNO3', 'quantity': 0.6, 'quantity_type': 'moles'}],
#   'description': '0.4M LITFSI 0.6M LINO3 DOL-DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DMeTHF',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI DMETHF'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.0327568743092422,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 0.2395373147852943,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiDFOB', 'quantity': 0.15, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7277058109054634,
#     'quantity_type': 'volume_percent'}],
#   'description': '1.2M LIFSI 0.15M LIDFOB EC-EMC-BTFE (0.175:0.825:2 MOL)'},
#  {'formulation': [{'compound_id': 'SL',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 3.25, 'quantity_type': 'moles'},
#    {'compound_id': 'LiNO3', 'quantity': 0.1, 'quantity_type': 'moles'}],
#   'description': '3.25M LITFSI 0.1M LINO3 SL'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 3.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.4663763909046928,
#     'quantity_type': 'moles'}],
#   'description': '3 M LITFSI 3WT% LINO3 DOL-DME (1:1 V)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LITFSI DOL-DME (1:1 VOL) 2WT% LINO3'},
#  {'formulation': [], 'description': 'LIFSI DMC-TTE (1:1.5:1.5 MOL)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 2.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '2M LIFSI 1M LITFSI DOL-DME (1:1 VOL)'},
#  {'formulation': [], 'description': 'LIFSI-AN-VC (0.52:1:0.09 MOLAR)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 2.0, 'quantity_type': 'moles'}],
#   'description': '1M LIFSI 2M LITFSI DOL-DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'}],
#   'description': '6 M LIFSI DMC'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 3.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '3 M LIFSI DOL-DME (1:1 VOL)'},
#  {'formulation': [], 'description': '1 LIFSI - 3 TMS- 3 TTE'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.333,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'GBL',
#     'quantity': 0.667,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiNO3', 'quantity': 0.3, 'quantity_type': 'moles'}],
#   'description': '1M LIFSI+0.3 M LINO3-FEC/GBL (1:2 V/V)'},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 8.0, 'quantity_type': 'moles'}],
#   'description': '8 M LIFSI PC'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1 M LIFSI DOL-DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI DEE'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.2487597448618001,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 0.47, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7512402551381998,
#     'quantity_type': 'volume_percent'}],
#   'description': '0.47M LIFSI DOL-BTFE (1:4 W/W)'},
#  {'formulation': [{'compound_id': 'FDMB',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1M LIFSI FDMB'},
#  {'formulation': [{'compound_id': 'TEP',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 2.2, 'quantity_type': 'moles'}],
#   'description': '2.2M LIFSI TEP (= 1:2 MR)'},
#  {'formulation': [{'compound_id': 'SL',
#     'quantity': 0.3357164358819988,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.3, 'quantity_type': 'moles'},
#    {'compound_id': 'D2',
#     'quantity': 0.6642835641180012,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiNO3', 'quantity': 0.04, 'quantity_type': 'moles'}],
#   'description': '1.3 M LITFSI 0.04 M LINO3 SL-D2 (1:2 WT)'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI DEE'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI DEE'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 4.0, 'quantity_type': 'moles'}],
#   'description': '4M LIFSI DME'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 5.0, 'quantity_type': 'moles'},
#    {'compound_id': 'ETFEC',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent'}],
#   'description': '5 M LIFSI/EC-ETFEC (3:7 VOL)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 2.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME', 'quantity': 0.5, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '2 M LIFSI 1 M LITFSI 3WT% LINO3 DOL-DME (1:1 V)'},
#  {'formulation': [], 'description': 'LIFSI-1.4TEP-3TTE'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.2879409351927809,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 2.54, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 0.712059064807219,
#     'quantity_type': 'volume_percent'}],
#   'description': '2.54M LIFSI DME-BTFE (1:4 W/W)'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 0.2450466662039999,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7549533337960002,
#     'quantity_type': 'volume_percent'}],
#   'description': '1M LIFSI DMC-BTFE (1:2 BY MOL)'},
#  {'formulation': [{'compound_id': 'TEP',
#     'quantity': 0.3039902023183154,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 0.6960097976816846,
#     'quantity_type': 'volume_percent'}],
#   'description': '1.2M LIFSI TEP-BTFE (1:3 MOL)'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 5.5, 'quantity_type': 'moles'}],
#   'description': '5.5M LIFSI DMC'},
#  {'formulation': [{'compound_id': 'THF',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 2.0, 'quantity_type': 'moles'},
#    {'compound_id': 'MTHF',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'}],
#   'description': '2M LIPF6 THF-MTHF (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1875049589731661,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FEMC',
#     'quantity': 0.6291512546468851,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'D2',
#     'quantity': 0.1833437863799486,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIPF6 FEC-FEMC-D2 (2:6:2 WT)'},
#  {'formulation': [], 'description': 'LIFSI-TEP 1:1 MOLAR'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'}],
#   'description': '10 M LIFSI DMC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 4.5, 'quantity_type': 'moles'}],
#   'description': '4.5 M LIFSI/DME (1 : 1)'},
#  {'formulation': [], 'description': 'LIFSI DME-TTE (1:1.2:3)'},
#  {'formulation': [{'compound_id': 'FDMA',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FEC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1M LITFSI IN FDMA/FEC (1:1 BY VOL)'},
#  {'formulation': [], 'description': 'LIFSI-DME-FB (1:1.2:3 MOLAR)'},
#  {'formulation': [], 'description': 'LIFSI-TEP 1:1.5 MOLAR'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 10.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '10 M LIFSI EC-DMC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.333,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.33, 'quantity_type': 'moles'},
#    {'compound_id': 'TTE',
#     'quantity': 0.667,
#     'quantity_type': 'volume_percent'}],
#   'description': '1.33 M LIFSI DME-TTE (1:2 VOL)'},
#  {'formulation': [], 'description': 'LIFSI-2.2DMC-3TTE'},
#  {'formulation': [{'compound_id': 'F3DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI F3DEE'},
#  {'formulation': [{'compound_id': 'F6DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI F6DEE'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 4.0, 'quantity_type': 'moles'}],
#   'description': '4 M LIFSI DEE'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.28, 'quantity_type': 'moles'},
#    {'compound_id': 'FEMC', 'quantity': 0.2, 'quantity_type': 'volume_percent'},
#    {'compound_id': 'D2', 'quantity': 0.7, 'quantity_type': 'volume_percent'}],
#   'description': '1.28M LIFSI FEC-FEMC-D2'},
#  {'formulation': [{'compound_id': 'FM',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.2, 'quantity_type': 'moles'},
#    {'compound_id': 'AN', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1.2M LITFSI 1M AN IN FM'},
#  {'formulation': [{'compound_id': 'MF',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.5, 'quantity_type': 'moles'},
#    {'compound_id': 'THF', 'quantity': 0.5, 'quantity_type': 'moles'}],
#   'description': '0.5M LITFSI 0.5M THF CH3F'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.0853015064815868,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FDMH',
#     'quantity': 0.9146984935184131,
#     'quantity_type': 'volume_percent'}],
#   'description': '1 M LIFSI DME-FDMH (1:6 MOLAR)'},
#  {'formulation': [], 'description': 'LIFSI-1.2DME-3BTFE'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'HFME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'}],
#   'description': '1.8 M LIFSI/DME (1 : 1) WITH HFME AT 50% CONCENTRATION'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 0.3297632468996617,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.8, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 0.6702367531003381,
#     'quantity_type': 'volume_percent'}],
#   'description': '1.8M LIFSI DEE-BTFE (1:4 W/W)'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 0.2422754453570001,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7577245546429999,
#     'quantity_type': 'volume_percent'}],
#   'description': '1.2M LIFSI DMC-BTFE (1:2 MOL)'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.1634492544449742,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'TFEO',
#     'quantity': 0.8365507455550258,
#     'quantity_type': 'volume_percent'}],
#   'description': '1M LIFSI DME-TFEO (1.2:3 MOL)'},
#  {'formulation': [{'compound_id': 'MTHF',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.7, 'quantity_type': 'moles'},
#    {'compound_id': 'TTE', 'quantity': 0.5, 'quantity_type': 'volume_percent'}],
#   'description': '1.7 M LIFSI METHF-TTE (1:1 VOL)'},
#  {'formulation': [], 'description': 'LIFSI-1DME-3TTE'},
#  {'formulation': [], 'description': 'LIFSI-1.2DME-3TFEO'},
#  {'formulation': [{'compound_id': 'F4DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI F4DEE'},
#  {'formulation': [{'compound_id': 'F5DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI F5DEE'}]

# %%
ds_df = pd.read_csv("datasets\\datascience.csv")
ml_list = construct_MLformulation_list_from_df(ds_df)

# %%
ml_list
# Out:
# [{'formulation': [{'compound_id': 'PC',
#     'quantity': 11.754564689287674,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiClO4', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FEC',
#     'quantity': 0.6854998397043016,
#     'quantity_type': 'moles'}],
#   'description': '1 M LICLO4-PC + 5% FEC',
#   'element_ratio': {'FC': 0.013968481227056,
#    'OC': 0.841984658474856,
#    'FO': 0.0165899474372349,
#    'InOr': 0.8763302140905531,
#    'F': 0.0041378841237753,
#    'sF': 0.0041378841237753,
#    'aF': 0.0,
#    'O': 0.2494211714310907,
#    'sO': 0.2252759630204788,
#    'aO': 0.0241452084106118,
#    'C': 0.2962300665701964,
#    'sC': 0.2962300665701964,
#    'aC': 0.0},
#   'CE': 80.0,
#   'LCE': 0.6989700043360189,
#   'current': 0.5,
#   'capacity': 0.083,
#   'cycle': 30.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 EC-DMC (1:1 V) 2% VC',
#   'element_ratio': {'FC': 0.1454777972232165,
#    'OC': 1.0,
#    'FO': 0.1454777972232165,
#    'InOr': 1.1697240967604192,
#    'F': 0.0382826294679182,
#    'sF': 0.0,
#    'aF': 0.0382826294679182,
#    'O': 0.2631510113476534,
#    'sO': 0.2631510113476534,
#    'aO': 0.0,
#    'C': 0.2631510113476534,
#    'sC': 0.2631510113476534,
#    'aC': 0.0},
#   'CE': 80.0,
#   'LCE': 0.6989700043360189,
#   'current': 0.6,
#   'capacity': 0.44,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiBF4', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIBF4 EC-DMC (1:1 V) 2% VC',
#   'element_ratio': {'FC': 0.1426340432436073,
#    'OC': 0.9847837183017344,
#    'FO': 0.1448379381104925,
#    'InOr': 1.1516640610825446,
#    'F': 0.0375624020575031,
#    'sF': 0.01202153591049,
#    'aF': 0.025540866147013,
#    'O': 0.2593409057566666,
#    'sO': 0.2593409057566666,
#    'aO': 0.0,
#    'C': 0.2633480843934966,
#    'sC': 0.2633480843934966,
#    'aC': 0.0},
#   'CE': 80.0,
#   'LCE': 0.6989700043360189,
#   'current': 0.6,
#   'capacity': 0.44,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 11.754564689287674,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFPFB', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1M LITFPFB PC',
#   'element_ratio': {'FC': 0.239912389958686,
#    'OC': 0.7250091260459701,
#    'FO': 0.3309094759497883,
#    'InOr': 0.98491421516788,
#    'F': 0.070253769100123,
#    'sF': 0.0,
#    'aF': 0.070253769100123,
#    'O': 0.2123050991467625,
#    'sO': 0.2064506183884189,
#    'aO': 0.0058544807583435,
#    'C': 0.2928309334595894,
#    'sC': 0.2752674911845586,
#    'aC': 0.0175634422750307},
#   'CE': 80.6,
#   'LCE': 0.7121982700697738,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 3.690498260953578,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 7.284217721357674,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 EC-EMC (3:7 WT) 2% WT VC',
#   'element_ratio': {'FC': 0.1458090023074853,
#    'OC': 0.8229825802430556,
#    'FO': 0.1771714320665485,
#    'InOr': 0.993093082935122,
#    'F': 0.0382949716284363,
#    'sF': 0.0,
#    'aF': 0.0382949716284363,
#    'O': 0.2161464248595795,
#    'sO': 0.2161464248595795,
#    'aO': 0.0,
#    'C': 0.262637910022037,
#    'sC': 0.262637910022037,
#    'aC': 0.0},
#   'CE': 82.0,
#   'LCE': 0.7447274948966941,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'}],
#   'description': '1 M LITFSI EC-DMC (1:1 V) 2% VC',
#   'element_ratio': {'FC': 0.1387494745805952,
#    'OC': 1.0462498248601984,
#    'FO': 0.132616007461827,
#    'InOr': 1.2543740367310914,
#    'F': 0.0364234489352111,
#    'sF': 0.0,
#    'aF': 0.0364234489352111,
#    'O': 0.2746534874057003,
#    'sO': 0.2503711881155596,
#    'aO': 0.0242822992901407,
#    'C': 0.2625123377606299,
#    'sC': 0.2503711881155596,
#    'aC': 0.0121411496450703},
#   'CE': 82.0,
#   'LCE': 0.7447274948966941,
#   'current': 0.6,
#   'capacity': 0.44,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 4.496831777611229,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 8.315015875130442,
#     'quantity_type': 'moles'}],
#   'description': '1M LIPF6 EC-DMC (3:7 V/V)',
#   'element_ratio': {'FC': 0.1561055090732374,
#    'OC': 1.0,
#    'FO': 0.1561055090732374,
#    'InOr': 1.182123093918777,
#    'F': 0.0392802526692617,
#    'sF': 0.0,
#    'aF': 0.0392802526692617,
#    'O': 0.2516263064798906,
#    'sO': 0.2516263064798906,
#    'aO': 0.0,
#    'C': 0.2516263064798906,
#    'sC': 0.2516263064798906,
#    'aC': 0.0},
#   'CE': 83.3,
#   'LCE': 0.7772835288524166,
#   'current': 0.4,
#   'capacity': 0.8,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 3.9985508282452793,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 6.0519011319000615,
#     'quantity_type': 'moles'}],
#   'description': '1M LIPF6 EC-DEC (1:2 W/W)',
#   'element_ratio': {'FC': 0.1419944987430708,
#    'OC': 0.7135544441110758,
#    'FO': 0.1989960260425022,
#    'InOr': 0.8792146926446586,
#    'F': 0.038236109961216,
#    'sF': 0.0,
#    'aF': 0.038236109961216,
#    'O': 0.1921450931540182,
#    'sO': 0.1921450931540182,
#    'aO': 0.0,
#    'C': 0.2692788122052644,
#    'sC': 0.2692788122052644,
#    'aC': 0.0},
#   'CE': 83.7,
#   'LCE': 0.7878123955960424,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 40.0},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 11.754564689287674,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiAsF6', 'quantity': 1.5, 'quantity_type': 'moles'}],
#   'description': '1.5 M LIASF6-PC',
#   'element_ratio': {'FC': 0.1914149999999999,
#    'OC': 0.75,
#    'FO': 0.25522,
#    'InOr': 0.9733175,
#    'F': 0.0546085552404699,
#    'sF': 0.0,
#    'aF': 0.0546085552404699,
#    'O': 0.2139665983875477,
#    'sO': 0.2139665983875477,
#    'aO': 0.0,
#    'C': 0.2852887978500636,
#    'sC': 0.2852887978500636,
#    'aC': 0.0},
#   'CE': 85.0,
#   'LCE': 0.8239087409443187,
#   'current': 1.0,
#   'capacity': 1.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiBETI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'},
#    {'compound_id': 'VC',
#     'quantity': 0.3137856495362945,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIBETI EC-DMC (1:1 V) 2% VC',
#   'element_ratio': {'FC': 0.221026679103045,
#    'OC': 1.0,
#    'FO': 0.2210266791030449,
#    'InOr': 1.2873346828339585,
#    'F': 0.0585723415344559,
#    'sF': 0.0,
#    'aF': 0.0585723415344559,
#    'O': 0.2650012286849267,
#    'sO': 0.2415722920711443,
#    'aO': 0.0234289366137823,
#    'C': 0.2650012286849267,
#    'sC': 0.2415722920711443,
#    'aC': 0.0234289366137823},
#   'CE': 86.0,
#   'LCE': 0.8538719643217619,
#   'current': 0.6,
#   'capacity': 0.44,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 4.991483273148464,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 7.923022269588579,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 EC-DMC (1:2 VOL)',
#   'element_ratio': {'FC': 0.1548646205138512,
#    'OC': 1.0,
#    'FO': 0.1548646205138512,
#    'InOr': 1.1806753905994931,
#    'F': 0.0392179675896959,
#    'sF': 0.0,
#    'aF': 0.0392179675896959,
#    'O': 0.2532403299060051,
#    'sO': 0.2532403299060051,
#    'aO': 0.0,
#    'C': 0.2532403299060051,
#    'sC': 0.2532403299060051,
#    'aC': 0.0},
#   'CE': 86.0,
#   'LCE': 0.8538719643217619,
#   'current': 0.5,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 3.604119180576201,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 6.269086607859447,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 EC-DEC (3:7 WT)',
#   'element_ratio': {'FC': 0.1423224490018803,
#    'OC': 0.7025894136548511,
#    'FO': 0.2025684506994245,
#    'InOr': 0.8686322708237114,
#    'F': 0.0382446348126403,
#    'sF': 0.0,
#    'aF': 0.0382446348126403,
#    'O': 0.1887985749043842,
#    'sO': 0.1887985749043842,
#    'aO': 0.0,
#    'C': 0.2687182175465172,
#    'sC': 0.2687182175465172,
#    'aC': 0.0},
#   'CE': 87.0,
#   'LCE': 0.8860566476931632,
#   'current': 0.1,
#   'capacity': 0.1,
#   'cycle': 160.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 4.126809447219165,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6-EC/DEC (1:1 VOL.)',
#   'element_ratio': {'FC': 0.1391523567266217,
#    'OC': 0.808581579885922,
#    'FO': 0.1720943936742336,
#    'InOr': 0.9709259960669808,
#    'F': 0.0381607130732046,
#    'sF': 0.0,
#    'aF': 0.0127202376910682,
#    'O': 0.2217429182814697,
#    'sO': 0.2217429182814697,
#    'aO': 0.0254404753821364,
#    'C': 0.2742369153558434,
#    'sC': 0.2742369153558434,
#    'aC': 0.0},
#   'CE': 88.0,
#   'LCE': 0.9208187539523752,
#   'current': 0.5,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 6.482964700884059,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.6, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 5.483966394079497,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiBOB', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (5:5 WT)',
#   'element_ratio': {'FC': 0.0814760570422074,
#    'OC': 0.9392558336046142,
#    'FO': 0.0867453297889287,
#    'InOr': 1.070522814394837,
#    'F': 0.0221826299358415,
#    'sF': 0.0,
#    'aF': 0.0221826299358415,
#    'O': 0.2557213165229416,
#    'sO': 0.2212150032894102,
#    'aO': 0.0345063132335313,
#    'C': 0.2722594924340807,
#    'sC': 0.2550063358173149,
#    'aC': 0.0172531566167656},
#   'CE': 88.1,
#   'LCE': 0.9244530386074692,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 6.368062430168407,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 4.747179494840347,
#     'quantity_type': 'moles'}],
#   'description': '1M LIPF6 EC-DEC (1:1 W/W)',
#   'element_ratio': {'FC': 0.1400557452898177,
#    'OC': 0.7783767459418648,
#    'FO': 0.1799331056843753,
#    'InOr': 0.9417751154466522,
#    'F': 0.0381849775908377,
#    'sF': 0.0,
#    'aF': 0.0381849775908377,
#    'O': 0.2122176319115996,
#    'sO': 0.2122176319115996,
#    'aO': 0.0,
#    'C': 0.2726412794549874,
#    'sC': 0.2726412794549874,
#    'aC': 0.0},
#   'CE': 90.3,
#   'LCE': 1.0132282657337552,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 40.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 4.991483273148464,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 7.923022269588579,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 EC-DMC (1:2 VOL) 2% TTFEB',
#   'element_ratio': {'FC': 0.1739387766669522,
#    'OC': 0.992909949272025,
#    'FO': 0.1751808175499495,
#    'InOr': 1.1946568469288068,
#    'F': 0.0440138816365565,
#    'sF': 0.0053822498844369,
#    'aF': 0.0386316317521196,
#    'O': 0.2512482944886748,
#    'sO': 0.2512482944886748,
#    'aO': 0.0,
#    'C': 0.2530423777834871,
#    'sC': 0.2530423777834871,
#    'aC': 0.0},
#   'CE': 91.0,
#   'LCE': 1.0457574905606752,
#   'current': 0.5,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 9.59422207414963,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.6, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 3.478196464087141,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiBOB', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (7:3 WT)',
#   'element_ratio': {'FC': 0.0791287883844928,
#    'OC': 0.98509309319726,
#    'FO': 0.0803262036156086,
#    'InOr': 1.1125783633722766,
#    'F': 0.0220432679379246,
#    'sF': 0.0,
#    'aF': 0.0220432679379246,
#    'O': 0.2744218815993108,
#    'sO': 0.2401323536958724,
#    'aO': 0.0342895279034384,
#    'C': 0.2785745667027625,
#    'sC': 0.2614298027510433,
#    'aC': 0.0171447639517192},
#   'CE': 91.6,
#   'LCE': 1.075720713938118,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 13.082165321795536,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.6, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 1.2295841365557074,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiBOB', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (9:1 WT)',
#   'element_ratio': {'FC': 0.076653099936215,
#    'OC': 1.0334381233672256,
#    'FO': 0.0741728974410757,
#    'InOr': 1.1569347843755722,
#    'F': 0.0218891004784874,
#    'sF': 0.0,
#    'aF': 0.0218891004784874,
#    'O': 0.2951091467860816,
#    'sO': 0.2610594349306568,
#    'aO': 0.0340497118554248,
#    'C': 0.2855605382783198,
#    'sC': 0.2685356823506074,
#    'aC': 0.0170248559277124},
#   'CE': 91.7,
#   'LCE': 1.0809219076239265,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V)',
#   'element_ratio': {'FC': 0.3349148440560682,
#    'OC': 1.0,
#    'FO': 0.3349148440560682,
#    'InOr': 1.3609681218326808,
#    'F': 0.08696295308457,
#    'sF': 0.0463734716710645,
#    'aF': 0.0405894814135054,
#    'O': 0.2596569086976972,
#    'sO': 0.2596569086976972,
#    'aO': 0.0,
#    'C': 0.2596569086976972,
#    'sC': 0.2596569086976972,
#    'aC': 0.0},
#   'CE': 91.78,
#   'LCE': 1.08512818245995,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.3709996794086032,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EC',
#     'quantity': 6.745247666416844,
#     'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 3.714128502497249,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL)',
#   'element_ratio': {'FC': 0.1717405726269909,
#    'OC': 0.826925360582763,
#    'FO': 0.207685700322408,
#    'InOr': 1.0219654285423558,
#    'F': 0.0472449141186303,
#    'sF': 0.0087875138960155,
#    'aF': 0.0384574002226148,
#    'O': 0.2274827493914509,
#    'sO': 0.2274827493914509,
#    'aO': 0.0,
#    'C': 0.2750946581577035,
#    'sC': 0.2750946581577035,
#    'aC': 0.0},
#   'CE': 92.2,
#   'LCE': 1.10790539730952,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 150.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'}],
#   'description': '1 M LITFSI EC-DMC (1:1 V) 5WT% FEC',
#   'element_ratio': {'FC': 0.1507150234799975,
#    'OC': 1.045087136966161,
#    'FO': 0.1442128777103852,
#    'InOr': 1.2634328658954,
#    'F': 0.0395419127487193,
#    'sF': 0.0040544425249806,
#    'aF': 0.0354874702237386,
#    'O': 0.2741912745693154,
#    'sO': 0.2505329610868229,
#    'aO': 0.0236583134824924,
#    'C': 0.2623621178280692,
#    'sC': 0.2505329610868229,
#    'aC': 0.0118291567412462},
#   'CE': 92.2,
#   'LCE': 1.10790539730952,
#   'current': 0.5,
#   'capacity': 0.5,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 9.631602308033733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 3.57, 'quantity_type': 'moles'}],
#   'description': '3.57 M LITFSI DME',
#   'element_ratio': {'FC': 0.4690537390648834,
#    'OC': 0.7345268695324417,
#    'FO': 0.6385794155678151,
#    'InOr': 1.4381074781297667,
#    'F': 0.1014081449177812,
#    'sF': 0.0,
#    'aF': 0.1014081449177812,
#    'O': 0.1588027149725937,
#    'sO': 0.0911972850274062,
#    'aO': 0.0676054299451875,
#    'C': 0.2161972850274063,
#    'sC': 0.1823945700548125,
#    'aC': 0.0338027149725937},
#   'CE': 92.8,
#   'LCE': 1.1426675035687313,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 12.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 4.126809447219165,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'}],
#   'description': '1M LIFSI EC/DEC (V 1:1)',
#   'element_ratio': {'FC': 0.0463841189088739,
#    'OC': 0.9013498177036698,
#    'FO': 0.051460729228353,
#    'InOr': 1.0173101149758546,
#    'F': 0.0125604655833376,
#    'sF': 0.0,
#    'aF': 0.0125604655833376,
#    'O': 0.2440786551547218,
#    'sO': 0.2189577239880464,
#    'aO': 0.0251209311666753,
#    'C': 0.2707923720188356,
#    'sC': 0.2707923720188356,
#    'aC': 0.0},
#   'CE': 93.0,
#   'LCE': 1.1549019599857435,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 4.496831777611229,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 0.1, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 8.315015875130442,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.1M LIDFP 0.4M LITFSI EC-DMC (3:7 V/V)',
#   'element_ratio': {'FC': 0.066266446287446,
#    'OC': 1.025487094725941,
#    'FO': 0.0646194833930656,
#    'InOr': 1.12488676415711,
#    'F': 0.0171336115887372,
#    'sF': 0.0,
#    'aF': 0.0171336115887372,
#    'O': 0.2651462173492991,
#    'sO': 0.2532844862494041,
#    'aO': 0.0118617310998949,
#    'C': 0.2585563667382463,
#    'sC': 0.2532844862494041,
#    'aC': 0.0052718804888422},
#   'CE': 93.6,
#   'LCE': 1.1938200260161125,
#   'current': 0.4,
#   'capacity': 0.8,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 9.631602308033733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.84, 'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 2.7, 'quantity_type': 'moles'}],
#   'description': '0.84 M LITFSI 2.7M LIDFP DME',
#   'element_ratio': {'FC': 0.2596600939846138,
#    'OC': 0.6969835195745346,
#    'FO': 0.37254839848024,
#    'InOr': 1.0864736605514556,
#    'F': 0.0568176756439675,
#    'sF': 0.0,
#    'aF': 0.0568176756439675,
#    'O': 0.1525108573161165,
#    'sO': 0.1048362559137069,
#    'aO': 0.0476746014024095,
#    'C': 0.2188155860689718,
#    'sC': 0.2096725118274138,
#    'aC': 0.009143074241558},
#   'CE': 93.9,
#   'LCE': 1.2146701649892333,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 12.0},
#  {'formulation': [{'compound_id': 'Tetraglyme',
#     'quantity': 4.539401464845507,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI IN TETRAGLYME',
#   'element_ratio': {'FC': 0.0440586719524281,
#    'OC': 0.5881173439048563,
#    'FO': 0.0749147638801072,
#    'InOr': 0.6982640237859267,
#    'F': 0.0112386160700742,
#    'sF': 0.0,
#    'aF': 0.0112386160700742,
#    'O': 0.1500187077684767,
#    'sO': 0.1275414756283282,
#    'aO': 0.0224772321401484,
#    'C': 0.2550829512566564,
#    'sC': 0.2550829512566564,
#    'aC': 0.0},
#   'CE': 94.0,
#   'LCE': 1.2218487496163568,
#   'current': 0.1,
#   'capacity': 0.2,
#   'cycle': 30.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0154646781076909,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.25WT% 12-CROWN-4',
#   'element_ratio': {'FC': 0.3338388000015344,
#    'OC': 0.9983935557446452,
#    'FO': 0.3343759563357186,
#    'InOr': 1.3582019272459571,
#    'F': 0.0867089581028968,
#    'sF': 0.0462380274540799,
#    'aF': 0.0404709306488169,
#    'O': 0.2593157685531663,
#    'sO': 0.2593157685531663,
#    'aO': 0.0,
#    'C': 0.2597330151633014,
#    'sC': 0.2597330151633014,
#    'aC': 0.0},
#   'CE': 94.05,
#   'LCE': 1.2254830342714504,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 9.631602308033733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.11, 'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 3.9, 'quantity_type': 'moles'}],
#   'description': '0.11 M LITFSI 3.9 M LIDFP DME',
#   'element_ratio': {'FC': 0.2183428133769766,
#    'OC': 0.7098258951246833,
#    'FO': 0.3076005184885851,
#    'InOr': 1.0373401151901482,
#    'F': 0.0471925358643742,
#    'sF': 0.0,
#    'aF': 0.0471925358643742,
#    'O': 0.1534215094833317,
#    'sO': 0.1074562026839885,
#    'aO': 0.0459653067993432,
#    'C': 0.216139634433008,
#    'sC': 0.214912405367977,
#    'aC': 0.001227229065031},
#   'CE': 94.3,
#   'LCE': 1.2441251443275083,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 12.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.3709996794086032,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EC',
#     'quantity': 6.745247666416844,
#     'quantity_type': 'moles'},
#    {'compound_id': 'RbNO3', 'quantity': 0.05, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 3.714128502497249,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL) 0.05 M RBNO3 0.05M 18-CROWN-6',
#   'element_ratio': {'FC': 0.1693727922771127,
#    'OC': 0.8258647937381958,
#    'FO': 0.2050853766395144,
#    'InOr': 1.0205136787582365,
#    'F': 0.0465438482535568,
#    'sF': 0.0086571162406004,
#    'aF': 0.0378867320129563,
#    'O': 0.2269486445899482,
#    'sO': 0.2260014762896243,
#    'aO': 0.0009471683003239,
#    'C': 0.2748012099688709,
#    'sC': 0.2748012099688709,
#    'aC': 0.0},
#   'CE': 94.4,
#   'LCE': 1.2518119729938,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 150.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 4.496831777611229,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 0.1, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 8.315015875130442,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 0.4, 'quantity_type': 'moles'}],
#   'description': '0.1M LIDFP 0.4M LIFSI EC-DMC (3:7 V/V)',
#   'element_ratio': {'FC': 0.0260175848455395,
#    'OC': 1.0468316527219714,
#    'FO': 0.0248536474588713,
#    'InOr': 1.1066720978667122,
#    'F': 0.0066957481633545,
#    'sF': 0.0,
#    'aF': 0.0066957481633545,
#    'O': 0.2694070628641078,
#    'sO': 0.2573547161700696,
#    'aO': 0.0120523466940381,
#    'C': 0.2573547161700696,
#    'sC': 0.2573547161700696,
#    'aC': 0.0},
#   'CE': 94.5,
#   'LCE': 1.2596373105057566,
#   'current': 0.4,
#   'capacity': 0.8,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 9.631602308033733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 2.0, 'quantity_type': 'moles'},
#    {'compound_id': 'LiDFOB', 'quantity': 2.0, 'quantity_type': 'moles'}],
#   'description': '2M LITFSI 2M LIDFOB DME',
#   'element_ratio': {'FC': 0.3438907120506754,
#    'OC': 0.7579180340380066,
#    'FO': 0.4537307421206324,
#    'InOr': 1.2737541021140195,
#    'F': 0.0776300941519007,
#    'sF': 0.0,
#    'aF': 0.0776300941519007,
#    'O': 0.171092868402691,
#    'sO': 0.0934627742507903,
#    'aO': 0.0776300941519007,
#    'C': 0.225740595577531,
#    'sC': 0.1869255485015806,
#    'aC': 0.0388150470759503},
#   'CE': 94.6,
#   'LCE': 1.2676062401770312,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.1237174248615273,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 2WT% 12-CROWN-4',
#   'element_ratio': {'FC': 0.3264958369384749,
#    'OC': 0.987431122765965,
#    'FO': 0.3306517582957116,
#    'InOr': 1.3393253165812151,
#    'F': 0.0849717044760453,
#    'sF': 0.0453116274297855,
#    'aF': 0.0396600770462598,
#    'O': 0.2569824667318197,
#    'sO': 0.2569824667318197,
#    'aO': 0.0,
#    'C': 0.2602535617998017,
#    'sC': 0.2602535617998017,
#    'aC': 0.0},
#   'CE': 94.7,
#   'LCE': 1.2757241303992115,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 9.631602308033733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 2.2, 'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 0.8, 'quantity_type': 'moles'}],
#   'description': '2.2 M LITFSI 0.8 M LIDFP DME',
#   'element_ratio': {'FC': 0.3447761008838504,
#    'OC': 0.691024596435647,
#    'FO': 0.4989346293348017,
#    'InOr': 1.2081887477614226,
#    'F': 0.0762471416811488,
#    'sF': 0.0,
#    'aF': 0.0762471416811488,
#    'O': 0.1528199030458245,
#    'sO': 0.0992408305131253,
#    'aO': 0.0535790725326991,
#    'C': 0.2211497301747004,
#    'sC': 0.1984816610262507,
#    'aC': 0.0226680691484496},
#   'CE': 94.9,
#   'LCE': 1.2924298239020642,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 12.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 4.126809447219165,
#     'quantity_type': 'moles'},
#    {'compound_id': 'FEC',
#     'quantity': 0.6854998397043016,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6-EC/DEC (1:1 VOL.) + 5 VOL% FEC',
#   'element_ratio': {'FC': 0.147992106301661,
#    'OC': 0.817295568904966,
#    'FO': 0.1810753807217439,
#    'InOr': 0.9874239566889412,
#    'F': 0.0407441839605101,
#    'sF': 0.0041777177837831,
#    'aF': 0.0365664661767269,
#    'O': 0.2250122783014944,
#    'sO': 0.2250122783014944,
#    'aO': 0.0,
#    'C': 0.2753132243246734,
#    'sC': 0.2753132243246734,
#    'aC': 0.0},
#   'CE': 95.0,
#   'LCE': 1.3010299956639817,
#   'current': 0.5,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 4.8158011540168655,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiNO3', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME',
#     'quantity': 7.15462080509733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'Li2S5', 'quantity': 0.15, 'quantity_type': 'moles'}],
#   'description': '0.02M LI2S5 0.15M LINO3 1M LITFSI DOL-DME (1:1 VOL)',
#   'element_ratio': {'FC': 0.1404262079490808,
#    'OC': 0.6644697586518395,
#    'FO': 0.2113357396941515,
#    'InOr': 0.8809601625733392,
#    'F': 0.0347536679925847,
#    'sF': 0.0,
#    'aF': 0.0347536679925847,
#    'O': 0.1644476605939003,
#    'sO': 0.1386720234994,
#    'aO': 0.0257756370945003,
#    'C': 0.247487050317463,
#    'sC': 0.2359024943199348,
#    'aC': 0.0115845559975282},
#   'CE': 95.0,
#   'LCE': 1.3010299956639817,
#   'current': 0.5,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'DEG-FTriEG',
#     'quantity': 2.4279247463721587,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI IN DEG-FTRIEG',
#   'element_ratio': {'FC': 0.5514842975206612,
#    'OC': 0.6029685950413223,
#    'FO': 0.9146152918343402,
#    'InOr': 1.2316793388429752,
#    'F': 0.1420464777669214,
#    'sF': 0.1287856049623967,
#    'aF': 0.0132608728045247,
#    'O': 0.1553073505714462,
#    'sO': 0.1287856049623967,
#    'aO': 0.0265217456090494,
#    'C': 0.2575712099247934,
#    'sC': 0.2575712099247934,
#    'aC': 0.0},
#   'CE': 95.0,
#   'LCE': 1.3010299956639817,
#   'current': 0.1,
#   'capacity': 0.2,
#   'cycle': 30.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 3.604119180576201,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiDFOB', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 6.269086607859447,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIDFOB EC-DEC (3:7 WT)',
#   'element_ratio': {'FC': 0.0452921211338725,
#    'OC': 0.7613518910919642,
#    'FO': 0.0594890768169139,
#    'InOr': 0.829290072792773,
#    'F': 0.0125877404256483,
#    'sF': 0.0,
#    'aF': 0.0125877404256483,
#    'O': 0.2115975083020523,
#    'sO': 0.1864220274507555,
#    'aO': 0.0251754808512967,
#    'C': 0.2779234028020471,
#    'sC': 0.2653356623763988,
#    'aC': 0.0125877404256483},
#   'CE': 95.0,
#   'LCE': 1.3010299956639817,
#   'current': 0.1,
#   'capacity': 0.1,
#   'cycle': 500.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 3.8200003625552177,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EMC',
#     'quantity': 6.048632152209076,
#     'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 1.1336924985453742,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-EMC-DMC (34.6:57.2:8.2 WT)',
#   'element_ratio': {'FC': 0.2514363767088479,
#    'OC': 0.8451276887732866,
#    'FO': 0.297512884797102,
#    'InOr': 1.1221685835499349,
#    'F': 0.0652345229482593,
#    'sF': 0.0253763637589749,
#    'aF': 0.0398581591892843,
#    'O': 0.219266210916371,
#    'sO': 0.219266210916371,
#    'aO': 0.0,
#    'C': 0.2594474347830666,
#    'sC': 0.2594474347830666,
#    'aC': 0.0},
#   'CE': 95.0,
#   'LCE': 1.3010299956639817,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 6.368062430168407,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 4.747179494840347,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiDFP', 'quantity': 0.15, 'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 IN EC/DEC + 0.15M LIDFP',
#   'element_ratio': {'FC': 0.1470585325543086,
#    'OC': 0.7853795332063556,
#    'FO': 0.1872451806248808,
#    'InOr': 0.9592820836078793,
#    'F': 0.0398658847828189,
#    'sF': 0.0,
#    'aF': 0.0398658847828189,
#    'O': 0.2129074011399237,
#    'sO': 0.2110090256740752,
#    'aO': 0.0018983754658485,
#    'C': 0.2710885529073026,
#    'sC': 0.2710885529073026,
#    'aC': 0.0},
#   'CE': 95.2,
#   'LCE': 1.3187587626244135,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.1082527467538363,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.75WT% 12-CROWN-4',
#   'element_ratio': {'FC': 0.327524992293278,
#    'OC': 0.988967566093378,
#    'FO': 0.331178699405753,
#    'InOr': 1.3419709740330257,
#    'F': 0.0852156092904021,
#    'sF': 0.0454416910097103,
#    'aF': 0.0397739182806918,
#    'O': 0.2573100547931008,
#    'sO': 0.2573100547931008,
#    'aO': 0.0,
#    'C': 0.2601804787284659,
#    'sC': 0.2601804787284659,
#    'aC': 0.0},
#   'CE': 95.35,
#   'LCE': 1.3325470471100462,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [],
#   'description': 'LIFSI-1.4DME-3TFEB',
#   'element_ratio': {'FC': 1.2288135593220335,
#    'OC': 0.6694915254237288,
#    'FO': 1.8354430379746836,
#    'InOr': 2.1525423728813555,
#    'F': 0.2700186219739292,
#    'sF': 0.2513966480446927,
#    'aF': 0.0186219739292364,
#    'O': 0.1471135940409683,
#    'sO': 0.1098696461824953,
#    'aO': 0.0372439478584729,
#    'C': 0.2197392923649906,
#    'sC': 0.2197392923649906,
#    'aC': 0.0},
#   'CE': 95.4,
#   'LCE': 1.3372421683184266,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0927880686461454,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.5WT% 12-CROWN-4',
#   'element_ratio': {'FC': 0.3285606562144214,
#    'OC': 0.990513726168878,
#    'FO': 0.3317073227094315,
#    'InOr': 1.3446333631055372,
#    'F': 0.0854609183559894,
#    'sF': 0.0455725034143053,
#    'aF': 0.0398884149416841,
#    'O': 0.2576395289013605,
#    'sO': 0.2576395289013605,
#    'aO': 0.0,
#    'C': 0.2601069748905571,
#    'sC': 0.2601069748905571,
#    'aC': 0.0},
#   'CE': 95.58,
#   'LCE': 1.354577730650908,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 9.631602308033733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 3.0, 'quantity_type': 'moles'}],
#   'description': '3M LITFSI DME',
#   'element_ratio': {'FC': 0.4042544707829104,
#    'OC': 0.7021272353914552,
#    'FO': 0.5757567153160317,
#    'InOr': 1.3085089415658209,
#    'F': 0.0890623352893636,
#    'sF': 0.0,
#    'aF': 0.0890623352893636,
#    'O': 0.1546874450964545,
#    'sO': 0.0953125549035454,
#    'aO': 0.0593748901929091,
#    'C': 0.2203125549035454,
#    'sC': 0.1906251098070908,
#    'aC': 0.0296874450964545},
#   'CE': 95.7,
#   'LCE': 1.3665315444204142,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0309293562153818,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.5WT% 12-CROWN-4',
#   'element_ratio': {'FC': 0.3327696482220488,
#    'OC': 0.9967974010825564,
#    'FO': 0.3338388000015344,
#    'InOr': 1.355453450682811,
#    'F': 0.0864564424999946,
#    'sF': 0.0461033721239383,
#    'aF': 0.0403530703760563,
#    'O': 0.258976615359261,
#    'sO': 0.258976615359261,
#    'aO': 0.0,
#    'C': 0.2598086783512913,
#    'sC': 0.2598086783512913,
#    'aC': 0.0},
#   'CE': 95.76,
#   'LCE': 1.3726341434072686,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'THF',
#     'quantity': 12.315544213913237,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI THF',
#   'element_ratio': {'FC': 0.0405990990990991,
#    'OC': 0.3311981981981982,
#    'FO': 0.1225824878274352,
#    'InOr': 0.4326959459459459,
#    'F': 0.011757646122638,
#    'sF': 0.0,
#    'aF': 0.011757646122638,
#    'O': 0.0959161975827229,
#    'sO': 0.0724009053374469,
#    'aO': 0.023515292245276,
#    'C': 0.2896036213497877,
#    'sC': 0.2896036213497877,
#    'aC': 0.0},
#   'CE': 95.8,
#   'LCE': 1.3767507096020992,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 40.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 6.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 4.126809447219165,
#     'quantity_type': 'moles'}],
#   'description': '6 M LIPF6 EC-DEC (1:1 VOL)',
#   'element_ratio': {'FC': 0.8349141403597302,
#    'OC': 0.808581579885922,
#    'FO': 1.0325663620454022,
#    'InOr': 1.7826480769722737,
#    'F': 0.1825282292192541,
#    'sF': 0.0,
#    'aF': 0.1825282292192541,
#    'O': 0.1767714269305514,
#    'sO': 0.1767714269305514,
#    'aO': 0.0,
#    'C': 0.2186191614153405,
#    'sC': 0.2186191614153405,
#    'aC': 0.0},
#   'CE': 96.0,
#   'LCE': 1.3979400086720373,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 90.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 13.709996794086033,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1 M LIFSI FEC',
#   'element_ratio': {'FC': 0.3819596515359926,
#    'OC': 1.0972526364053186,
#    'FO': 0.3481054762258953,
#    'InOr': 1.5521517652453003,
#    'F': 0.1067980980145558,
#    'sF': 0.093201901985444,
#    'aF': 0.0135961960291118,
#    'O': 0.3067980980145559,
#    'sO': 0.2796057059563323,
#    'aO': 0.0271923920582236,
#    'C': 0.2796057059563323,
#    'sC': 0.2796057059563323,
#    'aC': 0.0},
#   'CE': 96.11,
#   'LCE': 1.410050398674293,
#   'current': 0.25,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 9.631602308033733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 0.5, 'quantity_type': 'moles'},
#    {'compound_id': 'LiPO2F2', 'quantity': 0.5, 'quantity_type': 'moles'}],
#   'description': '0.5 M LIFSI+0.5 M LIPO2F2/DME',
#   'element_ratio': {'FC': 0.0519124423963133,
#    'OC': 0.5778686635944701,
#    'FO': 0.0898343268406467,
#    'InOr': 0.6816935483870968,
#    'F': 0.0123376338904343,
#    'sF': 0.0,
#    'aF': 0.0123376338904343,
#    'O': 0.1373376338904343,
#    'sO': 0.1188311830547828,
#    'aO': 0.0185064508356515,
#    'C': 0.2376623661095656,
#    'sC': 0.2376623661095656,
#    'aC': 0.0},
#   'CE': 96.4,
#   'LCE': 1.4436974992327136,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 170.0},
#  {'formulation': [{'compound_id': 'SL',
#     'quantity': 10.49355491016818,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 3.25, 'quantity_type': 'moles'}],
#   'description': '3.25M LITFSI SL',
#   'element_ratio': {'FC': 0.402275686840317,
#    'OC': 0.7011378434201585,
#    'FO': 0.5737469323835261,
#    'InOr': 1.5210283997772744,
#    'F': 0.0931217311161578,
#    'sF': 0.0,
#    'aF': 0.0931217311161578,
#    'O': 0.1623045385694713,
#    'sO': 0.1002233844920327,
#    'aO': 0.0620811540774385,
#    'C': 0.2314873460227847,
#    'sC': 0.2004467689840655,
#    'aC': 0.0310405770387192},
#   'CE': 96.5,
#   'LCE': 1.455931955649724,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'EA',
#     'quantity': 2.0475801325705985,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 5.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DCM',
#     'quantity': 12.527669194178872,
#     'quantity_type': 'moles'}],
#   'description': '5M LITFSI 1-4 (EA-DCM VOL)',
#   'element_ratio': {'FC': 0.9766264091204666,
#    'OC': 0.7843989948975665,
#    'FO': 1.2450633102200783,
#    'InOr': 3.064995447228933,
#    'F': 0.1751267808748424,
#    'sF': 0.0,
#    'aF': 0.1751267808748424,
#    'O': 0.1406569283965864,
#    'sO': 0.0239057411466914,
#    'aO': 0.1167511872498949,
#    'C': 0.1793180885130464,
#    'sC': 0.1209424948880989,
#    'aC': 0.0583755936249474},
#   'CE': 96.5,
#   'LCE': 1.455931955649724,
#   'current': 0.2,
#   'capacity': 0.5,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0773233905384545,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.25WT% 12-CROWN-4',
#   'element_ratio': {'FC': 0.3296028906398009,
#    'OC': 0.99206969546059,
#    'FO': 0.3322376362749147,
#    'InOr': 1.3473126430229665,
#    'F': 0.0857076438350177,
#    'sF': 0.0457040711291357,
#    'aF': 0.0400035727058819,
#    'O': 0.2579709053916387,
#    'sO': 0.2579709053916387,
#    'aO': 0.0,
#    'C': 0.260033046641819,
#    'sC': 0.260033046641819,
#    'aC': 0.0},
#   'CE': 96.75,
#   'LCE': 1.488116639021126,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 13.709996794086033,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 2.0, 'quantity_type': 'moles'}],
#   'description': '2 M LIFSI FEC',
#   'element_ratio': {'FC': 0.430585969738652,
#    'OC': 1.1945052728106371,
#    'FO': 0.3604722218810263,
#    'InOr': 1.7709701971572671,
#    'F': 0.1127307473465105,
#    'sF': 0.0872692526534894,
#    'aF': 0.0254614946930211,
#    'O': 0.3127307473465105,
#    'sO': 0.2618077579604683,
#    'aO': 0.0509229893860422,
#    'C': 0.2618077579604683,
#    'sC': 0.2618077579604683,
#    'aC': 0.0},
#   'CE': 96.76,
#   'LCE': 1.4894549897933895,
#   'current': 0.25,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': nan,
#     'quantity_type': 'moles'},
#    {'compound_id': 'BTFEC', 'quantity': nan, 'quantity_type': 'moles'}],
#   'description': 'LIFSI-1.2DME-3BTFEC',
#   'element_ratio': {'FC': 1.0101010101010102,
#    'OC': 0.7777777777777778,
#    'FO': 1.2987012987012987,
#    'InOr': 1.9393939393939392,
#    'F': 0.2403846153846154,
#    'sF': 0.2163461538461538,
#    'aF': 0.0240384615384615,
#    'O': 0.1850961538461538,
#    'sO': 0.1370192307692307,
#    'aO': 0.048076923076923,
#    'C': 0.2379807692307692,
#    'sC': 0.2379807692307692,
#    'aC': 0.0},
#   'CE': 96.8,
#   'LCE': 1.4948500216800935,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0463940343230727,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.75WT% 12-CROWN-4',
#   'element_ratio': {'FC': 0.3317073227094315,
#    'OC': 0.9952114374690126,
#    'FO': 0.333303366722772,
#    'InOr': 1.3527225224555155,
#    'F': 0.0862053933885625,
#    'sF': 0.045969498808416,
#    'aF': 0.0402358945801465,
#    'O': 0.2586394318070738,
#    'sO': 0.2586394318070738,
#    'aO': 0.0,
#    'C': 0.2598839021231877,
#    'sC': 0.2598839021231877,
#    'aC': 0.0},
#   'CE': 96.82,
#   'LCE': 1.4975728800155663,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 50.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 5.503189326568085,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 4.940618308980376,
#     'quantity_type': 'moles'}],
#   'description': '1M LIPF6 FEC-DEC (1:1 W/W)',
#   'element_ratio': {'FC': 0.2791178598823517,
#    'OC': 0.7602378314832817,
#    'FO': 0.3671454488627218,
#    'InOr': 1.0636200803066806,
#    'F': 0.0756972920947941,
#    'sF': 0.0362140027500061,
#    'aF': 0.039483289344788,
#    'O': 0.206177939367833,
#    'sO': 0.206177939367833,
#    'aO': 0.0,
#    'C': 0.2712018934463762,
#    'sC': 0.2712018934463762,
#    'aC': 0.0},
#   'CE': 97.0,
#   'LCE': 1.5228787452803372,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 40.0},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 4.8158011540168655,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME',
#     'quantity': 7.15462080509733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'Li2S5', 'quantity': 0.1, 'quantity_type': 'moles'},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.7772999999999999,
#     'quantity_type': 'moles'}],
#   'description': '0.1 M LI2S5 + 5% LINO3 IN 1 M LITFSI IN DOL/DME (1:1 VOL)',
#   'element_ratio': {'FC': 0.1404262079490808,
#    'OC': 0.7085144387750688,
#    'FO': 0.1981980892187037,
#    'InOr': 0.94904814993425,
#    'F': 0.034025150206438,
#    'sF': 0.0,
#    'aF': 0.034025150206438,
#    'O': 0.1716724431631258,
#    'sO': 0.1357651350644349,
#    'aO': 0.0359073080986908,
#    'C': 0.2422991456037588,
#    'sC': 0.2309574288682794,
#    'aC': 0.0113417167354793},
#   'CE': 97.0,
#   'LCE': 1.5228787452803372,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 230.0},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 4.8158011540168655,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFNFSI', 'quantity': 3.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DME',
#     'quantity': 7.15462080509733,
#     'quantity_type': 'moles'}],
#   'description': '3 M LIFNFSI IN DOL/DME',
#   'element_ratio': {'FC': 0.6032931719274949,
#    'OC': 0.7227621909726339,
#    'FO': 0.834704940937257,
#    'InOr': 1.507043314478377,
#    'F': 0.1371405705344346,
#    'sF': 0.0,
#    'aF': 0.1371405705344346,
#    'O': 0.1642982613478302,
#    'sO': 0.1094420331340564,
#    'aO': 0.0548562282137738,
#    'C': 0.2273199447894904,
#    'sC': 0.18617777362916,
#    'aC': 0.0411421711603304},
#   'CE': 97.0,
#   'LCE': 1.5228787452803372,
#   'current': 0.5,
#   'capacity': 1.5,
#   'cycle': 180.0},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 7.15462080509733,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.5, 'quantity_type': 'moles'},
#    {'compound_id': 'DME',
#     'quantity': 4.8158011540168655,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiNO3', 'quantity': 0.5, 'quantity_type': 'moles'}],
#   'description': '0.5 M LITFSI 0.5 M LINO3 DOL-DME (1:1 V)',
#   'element_ratio': {'FC': 0.0718957792491235,
#    'OC': 0.6576269522515341,
#    'FO': 0.1093260837363373,
#    'InOr': 0.7774532510000733,
#    'F': 0.0180447169030797,
#    'sF': 0.0,
#    'aF': 0.0180447169030797,
#    'O': 0.1650540866953426,
#    'sO': 0.1440019169750829,
#    'aO': 0.0210521697202596,
#    'C': 0.2509843705922373,
#    'sC': 0.2449694649578774,
#    'aC': 0.0060149056343599},
#   'CE': 97.0,
#   'LCE': 1.5228787452803372,
#   'current': 0.5,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiClO4', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'ES',
#     'quantity': 8.400286108754596,
#     'quantity_type': 'moles'}],
#   'description': '1 M LICLO4 EC-ES (1:1 VOL)',
#   'element_ratio': {'FC': 0.0,
#    'OC': 0.6741590980192358,
#    'FO': 0.0,
#    'InOr': 0.9134450965282822,
#    'F': 0.0,
#    'sF': 0.0,
#    'aF': 0.0,
#    'O': 0.1895120620882441,
#    'sO': 0.1608893577933064,
#    'aO': 0.0286227042949376,
#    'C': 0.2811088104351842,
#    'sC': 0.2811088104351842,
#    'aC': 0.0},
#   'CE': 97.0,
#   'LCE': 1.5228787452803372,
#   'current': 0.5,
#   'capacity': 0.5,
#   'cycle': 450.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.3709996794086032,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiPF6', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'EC',
#     'quantity': 6.745247666416844,
#     'quantity_type': 'moles'},
#    {'compound_id': 'RbNO3', 'quantity': 0.1, 'quantity_type': 'moles'},
#    {'compound_id': 'DEC',
#     'quantity': 3.714128502497249,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL) 0.1 M RBNO3 0.1M 18-CROWN-6',
#   'element_ratio': {'FC': 0.1670694130164346,
#    'OC': 0.824833073175744,
#    'FO': 0.2025493623493899,
#    'InOr': 1.0191014150131614,
#    'F': 0.0458632843512063,
#    'sF': 0.0085305319328374,
#    'aF': 0.0373327524183688,
#    'O': 0.2264301591435962,
#    'sO': 0.2245635215226778,
#    'aO': 0.0018666376209184,
#    'C': 0.2745163433757604,
#    'sC': 0.2745163433757604,
#    'aC': 0.0},
#   'CE': 97.1,
#   'LCE': 1.5376020021010437,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 150.0},
# ...
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'FDMA',
#     'quantity': 4.464981785709224,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FEC',
#     'quantity': 6.854998397043016,
#     'quantity_type': 'moles'}],
#   'description': '1M LITFSI IN FDMA/FEC (1:1 BY VOL)',
#   'element_ratio': {'FC': 0.7247464959948232,
#    'OC': 0.5663897777631391,
#    'FO': 1.2795896473574913,
#    'InOr': 1.5213129046211695,
#    'F': 0.1898150549887435,
#    'sF': 0.1531121489317211,
#    'aF': 0.0367029060570223,
#    'O': 0.1483405679162337,
#    'sO': 0.1238719638782188,
#    'aO': 0.0244686040380148,
#    'C': 0.2619054469910805,
#    'sC': 0.249671144972073,
#    'aC': 0.0122343020190074},
#   'CE': 99.3,
#   'LCE': 2.154901959985742,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 100.0},
#  {'formulation': [],
#   'description': 'LIFSI-DME-FB (1:1.2:3 MOLAR)',
#   'element_ratio': {'FC': 0.219298245614035,
#    'OC': 0.2807017543859649,
#    'FO': 0.78125,
#    'InOr': 0.631578947368421,
#    'F': 0.0766871165644172,
#    'sF': 0.0460122699386503,
#    'aF': 0.0306748466257668,
#    'O': 0.098159509202454,
#    'sO': 0.0368098159509202,
#    'aO': 0.0613496932515337,
#    'C': 0.3496932515337424,
#    'sC': 0.3496932515337424,
#    'aC': 0.0},
#   'CE': 99.3,
#   'LCE': 2.154901959985742,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 500.0},
#  {'formulation': [],
#   'description': 'LIFSI-TEP 1:1.5 MOLAR',
#   'element_ratio': {'FC': 0.2222222222222222,
#    'OC': 1.1111111111111112,
#    'FO': 0.1999999999999999,
#    'InOr': 1.8333333333333333,
#    'F': 0.0408163265306122,
#    'sF': 0.0,
#    'aF': 0.0408163265306122,
#    'O': 0.2040816326530612,
#    'sO': 0.1224489795918367,
#    'aO': 0.0816326530612244,
#    'C': 0.1836734693877551,
#    'sC': 0.1836734693877551,
#    'aC': 0.0},
#   'CE': 99.3,
#   'LCE': 2.154901959985742,
#   'current': 0.2,
#   'capacity': 1.0,
#   'cycle': 300.0},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 7.494719629352049,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 10.0, 'quantity_type': 'moles'},
#    {'compound_id': 'DMC',
#     'quantity': 5.9392970536646015,
#     'quantity_type': 'moles'}],
#   'description': '10 M LIFSI EC-DMC',
#   'element_ratio': {'FC': 0.4962526714065123,
#    'OC': 1.9925053428130248,
#    'FO': 0.2490596440288091,
#    'InOr': 3.2331370213293056,
#    'F': 0.0812285786990745,
#    'sF': 0.0,
#    'aF': 0.0812285786990745,
#    'O': 0.326141069605314,
#    'sO': 0.1636839122071648,
#    'aO': 0.1624571573981491,
#    'C': 0.1636839122071648,
#    'sC': 0.1636839122071648,
#    'aC': 0.0},
#   'CE': 99.3,
#   'LCE': 2.154901959985742,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 240.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 2.198601787299317,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.33, 'quantity_type': 'moles'},
#    {'compound_id': 'TTE', 'quantity': nan, 'quantity_type': 'moles'}],
#   'description': '1.33 M LIFSI DME-TTE (1:2 VOL)',
#   'element_ratio': {'FC': 0.5518873241396554,
#    'OC': 0.5551128506645212,
#    'FO': 0.9941894219868904,
#    'InOr': 1.215748785506375,
#    'F': 0.1300808561728235,
#    'sF': 0.1129926912896508,
#    'aF': 0.0170881648831726,
#    'O': 0.1308411187003544,
#    'sO': 0.0966647889340091,
#    'aO': 0.0341763297663453,
#    'C': 0.2357018371016372,
#    'sC': 0.2357018371016372,
#    'aC': 0.0},
#   'CE': 99.3,
#   'LCE': 2.154901959985742,
#   'current': 0.2,
#   'capacity': 0.5,
#   'cycle': 100.0},
#  {'formulation': [],
#   'description': 'LIFSI-2.2DMC-3TTE',
#   'element_ratio': {'FC': 1.2037037037037035,
#    'OC': 0.6296296296296297,
#    'FO': 1.9117647058823528,
#    'InOr': 1.972222222222222,
#    'F': 0.2876106194690265,
#    'sF': 0.2654867256637168,
#    'aF': 0.0221238938053097,
#    'O': 0.1504424778761062,
#    'sO': 0.1061946902654867,
#    'aO': 0.0442477876106194,
#    'C': 0.2389380530973451,
#    'sC': 0.2389380530973451,
#    'aC': 0.0},
#   'CE': 99.3,
#   'LCE': 2.154901959985742,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'F3DEE',
#     'quantity': nan,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI F3DEE',
#   'element_ratio': {'FC': 0.5643543925233645,
#    'OC': 0.4620421183800623,
#    'FO': 1.2214349516490248,
#    'InOr': 1.1229280996884736,
#    'F': 0.1414975746097286,
#    'sF': 0.1253623401220099,
#    'aF': 0.0161352344877187,
#    'O': 0.1158453623901107,
#    'sO': 0.0835748934146733,
#    'aO': 0.0322704689754374,
#    'C': 0.2507246802440199,
#    'sC': 0.2507246802440199,
#    'aC': 0.0},
#   'CE': 99.3,
#   'LCE': 2.154901959985742,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'F6DEE',
#     'quantity': nan,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI F6DEE',
#   'element_ratio': {'FC': 1.064606857142857,
#    'OC': 0.4625470476190476,
#    'FO': 2.301618532910114,
#    'InOr': 1.6240641904761903,
#    'F': 0.266838760561121,
#    'sF': 0.2506453521042036,
#    'aF': 0.0161934084569174,
#    'O': 0.115935267615236,
#    'sO': 0.0835484507014012,
#    'aO': 0.0323868169138348,
#    'C': 0.2506453521042036,
#    'sC': 0.2506453521042036,
#    'aC': 0.0},
#   'CE': 99.3,
#   'LCE': 2.154901959985742,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': nan,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 4.0, 'quantity_type': 'moles'}],
#   'description': '4 M LIFSI DEE',
#   'element_ratio': {'FC': 0.1871290577988915,
#    'OC': 0.7075914489311165,
#    'FO': 0.2644591848609358,
#    'InOr': 1.1754140934283452,
#    'F': 0.040659794381976,
#    'sF': 0.0,
#    'aF': 0.040659794381976,
#    'O': 0.153746954953963,
#    'sO': 0.0724273661900108,
#    'aO': 0.0813195887639521,
#    'C': 0.2172820985700326,
#    'sC': 0.2172820985700326,
#    'aC': 0.0},
#   'CE': 99.38,
#   'LCE': 2.2076083105017474,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.3709996794086032,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.28, 'quantity_type': 'moles'},
#    {'compound_id': 'FEMC',
#     'quantity': 1.6447368421052635,
#     'quantity_type': 'moles'},
#    {'compound_id': 'D2',
#     'quantity': 5.2028350927703135,
#     'quantity_type': 'moles'}],
#   'description': '1.28M LIFSI FEC-FEMC-D2',
#   'element_ratio': {'FC': 1.437470832000037,
#    'OC': 0.6148578970180965,
#    'FO': 2.33789114358196,
#    'InOr': 2.174220772445004,
#    'F': 0.3504395816996277,
#    'sF': 0.3306289551648768,
#    'aF': 0.0198106265347508,
#    'O': 0.1498955940107235,
#    'sO': 0.1102743409412218,
#    'aO': 0.0396212530695016,
#    'C': 0.2437890035041899,
#    'sC': 0.2437890035041899,
#    'aC': 0.0},
#   'CE': 99.4,
#   'LCE': 2.221848749616364,
#   'capacity': 2.0,
#   'cycle': 100.0},
#  {'formulation': [{'compound_id': 'FM',
#     'quantity': 16.365986954222247,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 1.2, 'quantity_type': 'moles'},
#    {'compound_id': 'AN', 'quantity': 1.0, 'quantity_type': 'moles'}],
#   'description': '1.2M LITFSI 1M AN IN FM',
#   'element_ratio': {'FC': 1.1348358739785631,
#    'OC': 0.2311472125346799,
#    'FO': 4.909580615462969,
#    'InOr': 1.5874991651923114,
#    'F': 0.2201812698907017,
#    'sF': 0.1529103702550292,
#    'aF': 0.0672708996356725,
#    'O': 0.0448472664237816,
#    'sO': 0.0,
#    'aO': 0.0448472664237816,
#    'C': 0.194020364476829,
#    'sC': 0.1529103702550292,
#    'aC': 0.0411099942217998},
#   'CE': 99.4,
#   'LCE': 2.221848749616364,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 200.0},
#  {'formulation': [{'compound_id': 'MF',
#     'quantity': 16.365986954222247,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiTFSI', 'quantity': 0.5, 'quantity_type': 'moles'},
#    {'compound_id': 'THF', 'quantity': 0.5, 'quantity_type': 'moles'}],
#   'description': '0.5M LITFSI 0.5M THF CH3F',
#   'element_ratio': {'FC': 1.0,
#    'OC': 0.129092310446638,
#    'FO': 7.746394781688899,
#    'InOr': 1.206547696714621,
#    'F': 0.2010380989070283,
#    'sF': 0.1698951316961787,
#    'aF': 0.0311429672108496,
#    'O': 0.025952472675708,
#    'sO': 0.0,
#    'aO': 0.025952472675708,
#    'C': 0.2010380989070283,
#    'sC': 0.1698951316961787,
#    'aC': 0.0311429672108496},
#   'CE': 99.4,
#   'LCE': 2.221848749616364,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 200.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.8215901867068065,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'FDMH',
#     'quantity': 4.098111530100418,
#     'quantity_type': 'moles'}],
#   'description': '1 M LIFSI DME-FDMH (1:6 MOLAR)',
#   'element_ratio': {'FC': 0.964338340360166,
#    'OC': 0.3836684974142764,
#    'FO': 2.5134676077376654,
#    'InOr': 1.4311755594439877,
#    'F': 0.252260823717337,
#    'sF': 0.2377567785720465,
#    'aF': 0.0145040451452904,
#    'O': 0.1003636660925155,
#    'sO': 0.0713555758019347,
#    'aO': 0.0290080902905808,
#    'C': 0.2615895408898928,
#    'sC': 0.2615895408898928,
#    'aC': 0.0},
#   'CE': 99.4,
#   'LCE': 2.221848749616364,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [],
#   'description': 'LIFSI-1.2DME-3BTFE',
#   'element_ratio': {'FC': 1.1904761904761905,
#    'OC': 0.5595238095238095,
#    'FO': 2.127659574468085,
#    'InOr': 1.9285714285714284,
#    'F': 0.2695417789757413,
#    'sF': 0.2425876010781671,
#    'aF': 0.0269541778975741,
#    'O': 0.1266846361185984,
#    'sO': 0.0727762803234501,
#    'aO': 0.0539083557951482,
#    'C': 0.2264150943396226,
#    'sC': 0.2264150943396226,
#    'aC': 0.0},
#   'CE': 99.4,
#   'LCE': 2.221848749616364,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 4.8158011540168655,
#     'quantity_type': 'moles'},
#    {'compound_id': 'HFME',
#     'quantity': 3.789709565446637,
#     'quantity_type': 'moles'}],
#   'description': '1.8 M LIFSI/DME (1 : 1) WITH HFME AT 50% CONCENTRATION',
#   'element_ratio': {'FC': 0.7651567190866807,
#    'OC': 0.5990728657986603,
#    'FO': 1.2772348119399533,
#    'InOr': 1.521105805717492,
#    'F': 0.1733938385896783,
#    'sF': 0.1496937961147221,
#    'aF': 0.0237000424749562,
#    'O': 0.1357572131363345,
#    'sO': 0.088357128186422,
#    'aO': 0.0474000849499124,
#    'C': 0.2266121884110847,
#    'sC': 0.2266121884110847,
#    'aC': 0.0},
#   'CE': 99.46,
#   'LCE': 2.2676062401770256,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 500.0},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 3.17394900618212,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.8, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 5.168353186392606,
#     'quantity_type': 'moles'}],
#   'description': '1.8M LIFSI DEE-BTFE (1:4 W/W)',
#   'element_ratio': {'FC': 1.0371872871364345,
#    'OC': 0.4657677771014019,
#    'FO': 2.2268334954193905,
#    'InOr': 1.6647808970638878,
#    'F': 0.2418013208963852,
#    'sF': 0.2166501576700986,
#    'aF': 0.0251511632262866,
#    'O': 0.1085852720438111,
#    'sO': 0.0582829455912377,
#    'aO': 0.0503023264525733,
#    'C': 0.2331317823649511,
#    'sC': 0.2331317823649511,
#    'aC': 0.0},
#   'CE': 99.5,
#   'LCE': 2.301029995663981,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 2.87789167756822,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'},
#    {'compound_id': 'BTFE',
#     'quantity': 5.842992193850629,
#     'quantity_type': 'moles'}],
#   'description': '1.2M LIFSI DMC-BTFE (1:2 MOL)',
#   'element_ratio': {'FC': 1.1703546220687335,
#    'OC': 0.6022896256088567,
#    'FO': 1.9431757950099475,
#    'InOr': 1.885124409663524,
#    'F': 0.2791628377048557,
#    'sF': 0.2612763608977995,
#    'aF': 0.0178864768070562,
#    'O': 0.1436631921938007,
#    'sO': 0.1078902385796883,
#    'aO': 0.0357729536141124,
#    'C': 0.238528419028588,
#    'sC': 0.238528419028588,
#    'aC': 0.0},
#   'CE': 99.5,
#   'LCE': 2.301029995663981,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.5742782163586062,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.0, 'quantity_type': 'moles'},
#    {'compound_id': 'TFEO',
#     'quantity': 3.9301910716085486,
#     'quantity_type': 'moles'}],
#   'description': '1M LIFSI DME-TFEO (1.2:3 MOL)',
#   'element_ratio': {'FC': 1.088923686863239,
#    'OC': 0.5608715076946277,
#    'FO': 1.9414851207883332,
#    'InOr': 1.738360498288943,
#    'F': 0.2677886149890842,
#    'sF': 0.2532686014452205,
#    'aF': 0.0145200135438637,
#    'O': 0.1379297796937787,
#    'sO': 0.1088897526060512,
#    'aO': 0.0290400270877274,
#    'C': 0.2459204609282381,
#    'sC': 0.2459204609282381,
#    'aC': 0.0},
#   'CE': 99.5,
#   'LCE': 2.301029995663981,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'MTHF',
#     'quantity': 3.301203884833809,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.7, 'quantity_type': 'moles'},
#    {'compound_id': 'TTE',
#     'quantity': 4.95762219900151,
#     'quantity_type': 'moles'}],
#   'description': '1.7 M LIFSI METHF-TTE (1:1 VOL)',
#   'element_ratio': {'FC': 0.7218854296257844,
#    'OC': 0.3646723137398274,
#    'FO': 1.9795454780282769,
#    'InOr': 1.2100619786704825,
#    'F': 0.1914019341556907,
#    'sF': 0.1695711850795981,
#    'aF': 0.0218307490760926,
#    'O': 0.0966898392990376,
#    'sO': 0.0530283411468523,
#    'aO': 0.0436614981521853,
#    'C': 0.2651417057342616,
#    'sC': 0.2651417057342616,
#    'aC': 0.0},
#   'CE': 99.5,
#   'LCE': 2.301029995663981,
#   'current': 1.0,
#   'capacity': 1.0,
#   'cycle': 40.0},
#  {'formulation': [],
#   'description': 'LIFSI-1DME-3TTE',
#   'element_ratio': {'FC': 1.368421052631579,
#    'OC': 0.4736842105263157,
#    'FO': 2.888888888888889,
#    'InOr': 2.0,
#    'F': 0.325,
#    'sF': 0.3,
#    'aF': 0.025,
#    'O': 0.1125,
#    'sO': 0.0625,
#    'aO': 0.05,
#    'C': 0.2375,
#    'sC': 0.2375,
#    'aC': 0.0},
#   'CE': 99.5,
#   'LCE': 2.301029995663981,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [],
#   'description': 'LIFSI-1.2DME-3TFEO',
#   'element_ratio': {'FC': 1.124031007751938,
#    'OC': 0.5968992248062015,
#    'FO': 1.883116883116883,
#    'InOr': 1.837209302325581,
#    'F': 0.2705223880597014,
#    'sF': 0.251865671641791,
#    'aF': 0.0186567164179104,
#    'O': 0.1436567164179104,
#    'sO': 0.1063432835820895,
#    'aO': 0.0373134328358208,
#    'C': 0.2406716417910447,
#    'sC': 0.2406716417910447,
#    'aC': 0.0},
#   'CE': 99.5,
#   'LCE': 2.301029995663981,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'F4DEE',
#     'quantity': 6.521510465972441,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI F4DEE',
#   'element_ratio': {'FC': 0.7280021505376344,
#    'OC': 0.4560043010752688,
#    'FO': 1.596480885862235,
#    'InOr': 1.2760096774193548,
#    'F': 0.1832215219162104,
#    'sF': 0.1677847808378955,
#    'aF': 0.0154367410783149,
#    'O': 0.1147658725755775,
#    'sO': 0.0838923904189477,
#    'aO': 0.0308734821566298,
#    'C': 0.2516771712568433,
#    'sC': 0.2516771712568433,
#    'aC': 0.0},
#   'CE': 99.5,
#   'LCE': 2.301029995663981,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0},
#  {'formulation': [{'compound_id': 'F5DEE',
#     'quantity': 6.19798973728211,
#     'quantity_type': 'moles'},
#    {'compound_id': 'LiFSI', 'quantity': 1.2, 'quantity_type': 'moles'}],
#   'description': '1.2 M LIFSI F5DEE',
#   'element_ratio': {'FC': 0.8978703875968993,
#    'OC': 0.4624074418604651,
#    'FO': 1.9417299686708724,
#    'InOr': 1.457083410852713,
#    'F': 0.225066728018617,
#    'sF': 0.2088894001551417,
#    'aF': 0.0161773278634753,
#    'O': 0.1159104157890073,
#    'sO': 0.0835557600620566,
#    'aO': 0.0323546557269506,
#    'C': 0.25066728018617,
#    'sC': 0.25066728018617,
#    'aC': 0.0},
#   'CE': 99.5,
#   'LCE': 2.301029995663981,
#   'current': 0.5,
#   'capacity': 1.0,
#   'cycle': 10.0}]

# %%
with open('datasets\\test_raw_mats_v2.pkl', 'rb') as f:
    test_mat_dict = pickle.load(f)

test_mat_list = []
for key, val in test_mat_dict.items():
    val["compound_id"] = key
    test_mat_list.append(val)

# %%
await init_db()

# %%
# bulk insert the compounds
mat_dict = await insert_compounds(test_mat_list)

# %%
mat_dict
# Out:
# {'DME': ObjectId('68be2a10c1da24c9aac1339a'),
#  'EC': ObjectId('68be2a10c1da24c9aac1339b'),
#  'PC': ObjectId('68be2a10c1da24c9aac1339c'),
#  'DEC': ObjectId('68be2a10c1da24c9aac1339d'),
#  'DMC': ObjectId('68be2a10c1da24c9aac1339e'),
#  'FEC': ObjectId('68be2a10c1da24c9aac1339f'),
#  'FDMB': ObjectId('68be2a10c1da24c9aac133a0'),
#  'BTFE': ObjectId('68be2a10c1da24c9aac133a1'),
#  'FEMC': ObjectId('68be2a10c1da24c9aac133a2'),
#  'D2': ObjectId('68be2a10c1da24c9aac133a3'),
#  'TTE': ObjectId('68be2a10c1da24c9aac133a4'),
#  'DOL': ObjectId('68be2a10c1da24c9aac133a5'),
#  'Diethyl ether': ObjectId('68be2a10c1da24c9aac133a6'),
#  'FM': ObjectId('68be2a10c1da24c9aac133a7'),
#  'DMB': ObjectId('68be2a10c1da24c9aac133a8'),
#  'TMS': ObjectId('68be2a10c1da24c9aac133a9'),
#  'TFEO': ObjectId('68be2a10c1da24c9aac133aa'),
#  'TFEC': ObjectId('68be2a10c1da24c9aac133ab'),
#  'TEP': ObjectId('68be2a10c1da24c9aac133ac'),
#  'EMC': ObjectId('68be2a10c1da24c9aac133ad'),
#  'VC': ObjectId('68be2a10c1da24c9aac133ae'),
#  'GBL': ObjectId('68be2a10c1da24c9aac133af'),
#  'HFME': ObjectId('68be2a10c1da24c9aac133b0'),
#  'DMSO': ObjectId('68be2a10c1da24c9aac133b1'),
#  'SL': ObjectId('68be2a10c1da24c9aac133b2'),
#  'AN': ObjectId('68be2a10c1da24c9aac133b3'),
#  'THF': ObjectId('68be2a10c1da24c9aac133b4'),
#  'MTHF': ObjectId('68be2a10c1da24c9aac133b5'),
#  'EA': ObjectId('68be2a10c1da24c9aac133b6'),
#  'DCM': ObjectId('68be2a10c1da24c9aac133b7'),
#  'ETFEC': ObjectId('68be2a10c1da24c9aac133b8'),
#  'FDMA': ObjectId('68be2a10c1da24c9aac133b9'),
#  'Tetraglyme': ObjectId('68be2a10c1da24c9aac133ba'),
#  'DEG-FTriEG': ObjectId('68be2a10c1da24c9aac133bb'),
#  'MTFP': ObjectId('68be2a10c1da24c9aac133bc'),
#  'FB': ObjectId('68be2a10c1da24c9aac133bd'),
#  'TMSB': ObjectId('68be2a10c1da24c9aac133be'),
#  '12-Crown-4': ObjectId('68be2a10c1da24c9aac133bf'),
#  '18-Crown-6': ObjectId('68be2a10c1da24c9aac133c0'),
#  'EGD': ObjectId('68be2a10c1da24c9aac133c1'),
#  'TTFEB': ObjectId('68be2a10c1da24c9aac133c2'),
#  'ES': ObjectId('68be2a10c1da24c9aac133c3'),
#  'DMeTHF': ObjectId('68be2a10c1da24c9aac133c4'),
#  'FDMH': ObjectId('68be2a10c1da24c9aac133c5'),
#  'FSA': ObjectId('68be2a10c1da24c9aac133c6'),
#  'BTFEC': ObjectId('68be2a10c1da24c9aac133c7'),
#  'TFEB': ObjectId('68be2a10c1da24c9aac133c8'),
#  '1,4-Dioxolane': ObjectId('68be2a10c1da24c9aac133c9'),
#  'Diethoxyethane': ObjectId('68be2a10c1da24c9aac133ca'),
#  'F3DEE': ObjectId('68be2a10c1da24c9aac133cb'),
#  'F4DEE': ObjectId('68be2a10c1da24c9aac133cc'),
#  'F5DEE': ObjectId('68be2a10c1da24c9aac133cd'),
#  'F6DEE': ObjectId('68be2a10c1da24c9aac133ce'),
#  'LiFSI': ObjectId('68be2a10c1da24c9aac133cf'),
#  'LiPF6': ObjectId('68be2a10c1da24c9aac133d0'),
#  'LiTFSI': ObjectId('68be2a10c1da24c9aac133d1'),
#  'LiBOB': ObjectId('68be2a10c1da24c9aac133d2'),
#  'LiDFP': ObjectId('68be2a10c1da24c9aac133d3'),
#  'LiNO3': ObjectId('68be2a10c1da24c9aac133d4'),
#  'LiDFOB': ObjectId('68be2a10c1da24c9aac133d5'),
#  'LiFNFSI': ObjectId('68be2a10c1da24c9aac133d6'),
#  'LiPO2F2': ObjectId('68be2a10c1da24c9aac133d7'),
#  'LiAsF6': ObjectId('68be2a10c1da24c9aac133d8'),
#  'LiClO4': ObjectId('68be2a10c1da24c9aac133d9'),
#  'Li2S5': ObjectId('68be2a10c1da24c9aac133da'),
#  'RbNO3': ObjectId('68be2a10c1da24c9aac133db'),
#  'LiBETI': ObjectId('68be2a10c1da24c9aac133dc'),
#  'LiTFPFB': ObjectId('68be2a10c1da24c9aac133dd'),
#  'LiBF4': ObjectId('68be2a10c1da24c9aac133de'),
#  'TMS-FNFSI': ObjectId('68be2a10c1da24c9aac133df'),
#  'DEE': ObjectId('68be2a10c1da24c9aac133e0'),
#  'MF': ObjectId('68be2a10c1da24c9aac133e1')}

# %%
prep_ml_id_dict = await insert_preparation_ML_formulations(prep_list, ml_list, mat_dict)

# %%
prep_list
# Out:
# [{'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339c')},
#    {'compound_id': 'LiClO4',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d9')},
#    {'compound_id': 'FEC',
#     'quantity': 0.05,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')}],
#   'description': '1 M LICLO4-PC + 5% FEC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LIPF6 EC-DMC (1:1 V) 2% VC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiBF4',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133de')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LIBF4 EC-DMC (1:1 V) 2% VC'},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339c')},
#    {'compound_id': 'LiTFPFB',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133dd')}],
#   'description': '1M LITFPFB PC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.2462065589818893,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'EMC',
#     'quantity': 0.7537934410181106,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ad')}],
#   'description': '1 M LIPF6 EC-EMC (3:7 WT) 2% WT VC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LITFSI EC-DMC (1:1 V) 2% VC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1M LIPF6 EC-DMC (3:7 V/V)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.2667578659370725,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DEC',
#     'quantity': 0.7332421340629275,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1M LIPF6 EC-DEC (1:2 W/W)'},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339c')},
#    {'compound_id': 'LiAsF6',
#     'quantity': 1.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d8')}],
#   'description': '1.5 M LIASF6-PC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiBETI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133dc')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'VC',
#     'quantity': 0.02,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ae')}],
#   'description': '1 M LIBETI EC-DMC (1:1 V) 2% VC'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.333,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.667,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LIPF6 EC-DMC (1:2 VOL)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.2404438964241677,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DEC',
#     'quantity': 0.7595561035758323,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1 M LIPF6 EC-DEC (3:7 WT)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1 M LIPF6-EC/DEC (1:1 VOL.)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.4325021496130696,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.6,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'EMC',
#     'quantity': 0.5674978503869303,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ad')},
#    {'compound_id': 'LiBOB',
#     'quantity': 0.4,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d2')}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (5:5 WT)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.4248366013071895,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DEC',
#     'quantity': 0.5751633986928105,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1M LIPF6 EC-DEC (1:1 W/W)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.333,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.667,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LIPF6 EC-DMC (1:2 VOL) 2% TTFEB'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.6400654426467914,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.6,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'EMC',
#     'quantity': 0.3599345573532084,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ad')},
#    {'compound_id': 'LiBOB',
#     'quantity': 0.4,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d2')}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (7:3 WT)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.8727588201272412,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.6,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'EMC',
#     'quantity': 0.1272411798727588,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ad')},
#    {'compound_id': 'LiBOB',
#     'quantity': 0.4,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d2')}],
#   'description': '0.6M LITFSI 0.4M LIBOB EC-EMC (9:1 WT)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'EC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'DEC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LITFSI EC-DMC (1:1 V) 5WT% FEC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 3.57,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')}],
#   'description': '3.57 M LITFSI DME'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'DEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1M LIFSI EC/DEC (V 1:1)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiDFP',
#     'quantity': 0.1,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d3')},
#    {'compound_id': 'DMC',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.4,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')}],
#   'description': '0.1M LIDFP 0.4M LITFSI EC-DMC (3:7 V/V)'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.84,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'LiDFP',
#     'quantity': 2.7,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d3')}],
#   'description': '0.84 M LITFSI 2.7M LIDFP DME'},
#  {'formulation': [{'compound_id': 'Tetraglyme',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ba')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI IN TETRAGLYME'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0025,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bf')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.25WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.11,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'LiDFP',
#     'quantity': 3.9,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d3')}],
#   'description': '0.11 M LITFSI 3.9 M LIDFP DME'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'EC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'RbNO3',
#     'quantity': 0.05,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133db')},
#    {'compound_id': 'DEC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL) 0.05 M RBNO3 0.05M 18-CROWN-6'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiDFP',
#     'quantity': 0.1,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d3')},
#    {'compound_id': 'DMC',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'LiFSI',
#     'quantity': 0.4,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '0.1M LIDFP 0.4M LIFSI EC-DMC (3:7 V/V)'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 2.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'LiDFOB',
#     'quantity': 2.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d5')}],
#   'description': '2M LITFSI 2M LIDFOB DME'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.02,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bf')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 2WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 2.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'LiDFP',
#     'quantity': 0.8,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d3')}],
#   'description': '2.2 M LITFSI 0.8 M LIDFP DME'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')},
#    {'compound_id': 'FEC',
#     'quantity': 0.05,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')}],
#   'description': '1 M LIPF6-EC/DEC (1:1 VOL.) + 5 VOL% FEC'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiNO3',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'Li2S5',
#     'quantity': 0.15,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133da')}],
#   'description': '0.02M LI2S5 0.15M LINO3 1M LITFSI DOL-DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DEG-FTriEG',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bb')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI IN DEG-FTRIEG'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.2404438964241677,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiDFOB',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d5')},
#    {'compound_id': 'DEC',
#     'quantity': 0.7595561035758323,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1 M LIDFOB EC-DEC (3:7 WT)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.278628829745826,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'EMC',
#     'quantity': 0.6259312142878466,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ad')},
#    {'compound_id': 'DMC',
#     'quantity': 0.0954399559663273,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LIPF6 FEC-EMC-DMC (34.6:57.2:8.2 WT)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.4248366013071895,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DEC',
#     'quantity': 0.5751633986928105,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')},
#    {'compound_id': 'LiDFP',
#     'quantity': 0.15,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d3')}],
#   'description': '1 M LIPF6 IN EC/DEC + 0.15M LIDFP'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0175,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bf')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.75WT% 12-CROWN-4'},
#  {'formulation': [], 'description': 'LIFSI-1.4DME-3TFEB'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.015,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bf')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.5WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 3.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')}],
#   'description': '3M LITFSI DME'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.005,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bf')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.5WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'THF',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b4')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI THF'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 6.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '6 M LIPF6 EC-DEC (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 0.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'LiPO2F2',
#     'quantity': 0.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d7')}],
#   'description': '0.5 M LIFSI+0.5 M LIPO2F2/DME'},
#  {'formulation': [{'compound_id': 'SL',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b2')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 3.25,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')}],
#   'description': '3.25M LITFSI SL'},
#  {'formulation': [{'compound_id': 'EA',
#     'quantity': 0.2,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b6')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 5.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DCM',
#     'quantity': 0.8,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b7')}],
#   'description': '5M LITFSI 1-4 (EA-DCM VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0125,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bf')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 1.25WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 2.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '2 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.2857,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'BTFEC',
#     'quantity': 0.7143,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133c7')}],
#   'description': 'LIFSI-1.2DME-3BTFEC'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.0075,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bf')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.75WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.4013997529847674,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DEC',
#     'quantity': 0.5986002470152326,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1M LIPF6 FEC-DEC (1:1 W/W)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'Li2S5',
#     'quantity': 0.1,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133da')},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.7772999999999999,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')}],
#   'description': '0.1 M LI2S5 + 5% LINO3 IN 1 M LITFSI IN DOL/DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiFNFSI',
#     'quantity': 3.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d6')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')}],
#   'description': '3 M LIFNFSI IN DOL/DME'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')}],
#   'description': '0.5 M LITFSI 0.5 M LINO3 DOL-DME (1:1 V)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiClO4',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d9')},
#    {'compound_id': 'ES',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133c3')}],
#   'description': '1 M LICLO4 EC-ES (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'EC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'RbNO3',
#     'quantity': 0.1,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133db')},
#    {'compound_id': 'DEC',
#     'quantity': 0.45,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1 M LIPF6 FEC-EC-DEC (2:9:9 VOL) 0.1 M RBNO3 0.1M 18-CROWN-6'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 3.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '3 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': '12-Crown-4',
#     'quantity': 0.01,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bf')}],
#   'description': '1 M LIPF6 FEC-DMC (1:1 V) 0.1WT% 12-CROWN-4'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1M LIFSI DME'},
#  {'formulation': [{'compound_id': 'TEP',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ac')},
#    {'compound_id': 'LiFSI',
#     'quantity': 3.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '3.2M LIFSI TEP'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')}],
#   'description': '1 M LITFSI IN DOL/DME WITH 5WT% TMS-FNFSI'},
#  {'formulation': [], 'description': 'LIFSI SL (1:3 MOLAR)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 4.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '4 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.3333,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'DEC',
#     'quantity': 0.6667,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339d')}],
#   'description': '1M LIFSI FEC-DEC (1:2 BY VOLUME)'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'ETFEC',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b8')}],
#   'description': '1 M LIFSI/EC-ETFEC (3:7 VOL)'},
#  {'formulation': [{'compound_id': 'PC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339c')},
#    {'compound_id': 'LiFSI',
#     'quantity': 5.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '5 M LIFSI PC'},
#  {'formulation': [{'compound_id': '1,4-Dioxolane',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133c9')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI 1,4-DIOXOLANE'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.50944669365722,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'TFEC',
#     'quantity': 0.49055330634278,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ab')}],
#   'description': '1M LIPF6 FEC-TFEC (1:1 W/W)'},
#  {'formulation': [{'compound_id': 'MTFP',
#     'quantity': 0.9,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133bc')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')}],
#   'description': '1 M LIPF6 MTFP-FEC (9:1 VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 5.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '5 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 6.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '6 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'DMB',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a8')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1M LIFSI DMB'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.15,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 0.3,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.15,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.35,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')},
#    {'compound_id': 'DME',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')}],
#   'description': '1 M LIPF6 EC-DMC (1:1 V), 0.5 M LINO3 TEGDME, 70%'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 7.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '7 M LIFSI FEC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')}],
#   'description': '1M LITFSI DME-DOL (1:1) 3% LINO3'},
#  {'formulation': [{'compound_id': 'FSA',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133c6')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI FSA'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 4.6,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 2.3,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')}],
#   'description': '4.6 M LIFSI 2.3 M LITFSI DME'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.25,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiPF6',
#     'quantity': 0.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'DMC',
#     'quantity': 0.25,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.25,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')}],
#   'description': '1 M LIPF6 EC-DMC (1:1 V), 0.5 M LINO3 TEGDME, 50%'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.3863731762282948,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'EMC',
#     'quantity': 0.531554576832353,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ad')},
#    {'compound_id': 'TMSB',
#     'quantity': 0.01,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133be')},
#    {'compound_id': 'DMC',
#     'quantity': 0.0820722469393522,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '1 M LIPF6 FEC-EMC-DMC (34.6:57.2:8.2 WT) 1WT% TMSB'},
#  {'formulation': [{'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'SL',
#     'quantity': 2.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133b2')}],
#   'description': 'LIFSI SL (1:2.5 MOLAR)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'FEMC',
#     'quantity': 0.2,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a2')},
#    {'compound_id': 'D2',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a3')}],
#   'description': '1M LIFSI FEC-FEMC-D2 (234:280:793 BY MOL)'},
#  {'formulation': [], 'description': '1 LIFSI - 3 TMS'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 0.2422754453570001,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7577245546429999,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a1')}],
#   'description': '1.2M LIFSI DMC-BTFE (1:2 MOL)'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 4.6,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '4.6 M LIFSI DME'},
#  {'formulation': [{'compound_id': 'MTHF',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b5')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI METHF'},
#  {'formulation': [], 'description': 'LIFSI DMC (1:1.5 MOL)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.4,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.6,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')}],
#   'description': '0.4M LITFSI 0.6M LINO3 DOL-DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DMeTHF',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133c4')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI DMETHF'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.0327568743092422,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'EMC',
#     'quantity': 0.2395373147852943,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ad')},
#    {'compound_id': 'LiDFOB',
#     'quantity': 0.15,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d5')},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7277058109054634,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a1')}],
#   'description': '1.2M LIFSI 0.15M LIDFOB EC-EMC-BTFE (0.175:0.825:2 MOL)'},
#  {'formulation': [{'compound_id': 'SL',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b2')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 3.25,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.1,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')}],
#   'description': '3.25M LITFSI 0.1M LINO3 SL'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 3.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.4663763909046928,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')}],
#   'description': '3 M LITFSI 3WT% LINO3 DOL-DME (1:1 V)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')}],
#   'description': '1 M LITFSI DOL-DME (1:1 VOL) 2WT% LINO3'},
#  {'formulation': [], 'description': 'LIFSI DMC-TTE (1:1.5:1.5 MOL)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiFSI',
#     'quantity': 2.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')}],
#   'description': '2M LIFSI 1M LITFSI DOL-DME (1:1 VOL)'},
#  {'formulation': [], 'description': 'LIFSI-AN-VC (0.52:1:0.09 MOLAR)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
# ...
#   'description': '1 M LIFSI DOL-DME (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133e0')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI DEE'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.2487597448618001,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiFSI',
#     'quantity': 0.47,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7512402551381998,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a1')}],
#   'description': '0.47M LIFSI DOL-BTFE (1:4 W/W)'},
#  {'formulation': [{'compound_id': 'FDMB',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a0')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1M LIFSI FDMB'},
#  {'formulation': [{'compound_id': 'TEP',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ac')},
#    {'compound_id': 'LiFSI',
#     'quantity': 2.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '2.2M LIFSI TEP (= 1:2 MR)'},
#  {'formulation': [{'compound_id': 'SL',
#     'quantity': 0.3357164358819988,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b2')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.3,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'D2',
#     'quantity': 0.6642835641180012,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a3')},
#    {'compound_id': 'LiNO3',
#     'quantity': 0.04,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d4')}],
#   'description': '1.3 M LITFSI 0.04 M LINO3 SL-D2 (1:2 WT)'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133e0')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1.2 M LIFSI DEE'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133e0')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1 M LIFSI DEE'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 4.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '4M LIFSI DME'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.3,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiFSI',
#     'quantity': 5.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'ETFEC',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b8')}],
#   'description': '5 M LIFSI/EC-ETFEC (3:7 VOL)'},
#  {'formulation': [{'compound_id': 'DOL',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a5')},
#    {'compound_id': 'LiFSI',
#     'quantity': 2.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')}],
#   'description': '2 M LIFSI 1 M LITFSI 3WT% LINO3 DOL-DME (1:1 V)'},
#  {'formulation': [], 'description': 'LIFSI-1.4TEP-3TTE'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.2879409351927809,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 2.54,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'BTFE',
#     'quantity': 0.712059064807219,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a1')}],
#   'description': '2.54M LIFSI DME-BTFE (1:4 W/W)'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 0.2450466662039999,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7549533337960002,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a1')}],
#   'description': '1M LIFSI DMC-BTFE (1:2 BY MOL)'},
#  {'formulation': [{'compound_id': 'TEP',
#     'quantity': 0.3039902023183154,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ac')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'BTFE',
#     'quantity': 0.6960097976816846,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a1')}],
#   'description': '1.2M LIFSI TEP-BTFE (1:3 MOL)'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'LiFSI',
#     'quantity': 5.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '5.5M LIFSI DMC'},
#  {'formulation': [{'compound_id': 'THF',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b4')},
#    {'compound_id': 'LiPF6',
#     'quantity': 2.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'MTHF',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b5')}],
#   'description': '2M LIPF6 THF-MTHF (1:1 VOL)'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1875049589731661,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiPF6',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d0')},
#    {'compound_id': 'FEMC',
#     'quantity': 0.6291512546468851,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a2')},
#    {'compound_id': 'D2',
#     'quantity': 0.1833437863799486,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a3')}],
#   'description': '1 M LIPF6 FEC-FEMC-D2 (2:6:2 WT)'},
#  {'formulation': [], 'description': 'LIFSI-TEP 1:1 MOLAR'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '10 M LIFSI DMC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 4.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '4.5 M LIFSI/DME (1 : 1)'},
#  {'formulation': [], 'description': 'LIFSI DME-TTE (1:1.2:3)'},
#  {'formulation': [{'compound_id': 'FDMA',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b9')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'FEC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')}],
#   'description': '1M LITFSI IN FDMA/FEC (1:1 BY VOL)'},
#  {'formulation': [], 'description': 'LIFSI-DME-FB (1:1.2:3 MOLAR)'},
#  {'formulation': [], 'description': 'LIFSI-TEP 1:1.5 MOLAR'},
#  {'formulation': [{'compound_id': 'EC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339b')},
#    {'compound_id': 'LiFSI',
#     'quantity': 10.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'DMC',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')}],
#   'description': '10 M LIFSI EC-DMC'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.333,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.33,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'TTE',
#     'quantity': 0.667,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a4')}],
#   'description': '1.33 M LIFSI DME-TTE (1:2 VOL)'},
#  {'formulation': [], 'description': 'LIFSI-2.2DMC-3TTE'},
#  {'formulation': [{'compound_id': 'F3DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133cb')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1.2 M LIFSI F3DEE'},
#  {'formulation': [{'compound_id': 'F6DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133ce')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1.2 M LIFSI F6DEE'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133e0')},
#    {'compound_id': 'LiFSI',
#     'quantity': 4.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '4 M LIFSI DEE'},
#  {'formulation': [{'compound_id': 'FEC',
#     'quantity': 0.1,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339f')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.28,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'FEMC',
#     'quantity': 0.2,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a2')},
#    {'compound_id': 'D2',
#     'quantity': 0.7,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a3')}],
#   'description': '1.28M LIFSI FEC-FEMC-D2'},
#  {'formulation': [{'compound_id': 'FM',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a7')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'AN',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133b3')}],
#   'description': '1.2M LITFSI 1M AN IN FM'},
#  {'formulation': [{'compound_id': 'MF',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133e1')},
#    {'compound_id': 'LiTFSI',
#     'quantity': 0.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133d1')},
#    {'compound_id': 'THF',
#     'quantity': 0.5,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133b4')}],
#   'description': '0.5M LITFSI 0.5M THF CH3F'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.0853015064815868,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'FDMH',
#     'quantity': 0.9146984935184131,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133c5')}],
#   'description': '1 M LIFSI DME-FDMH (1:6 MOLAR)'},
#  {'formulation': [], 'description': 'LIFSI-1.2DME-3BTFE'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'HFME',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b0')}],
#   'description': '1.8 M LIFSI/DME (1 : 1) WITH HFME AT 50% CONCENTRATION'},
#  {'formulation': [{'compound_id': 'DEE',
#     'quantity': 0.3297632468996617,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133e0')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.8,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'BTFE',
#     'quantity': 0.6702367531003381,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a1')}],
#   'description': '1.8M LIFSI DEE-BTFE (1:4 W/W)'},
#  {'formulation': [{'compound_id': 'DMC',
#     'quantity': 0.2422754453570001,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339e')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'BTFE',
#     'quantity': 0.7577245546429999,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a1')}],
#   'description': '1.2M LIFSI DMC-BTFE (1:2 MOL)'},
#  {'formulation': [{'compound_id': 'DME',
#     'quantity': 0.1634492544449742,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac1339a')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.0,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'TFEO',
#     'quantity': 0.8365507455550258,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133aa')}],
#   'description': '1M LIFSI DME-TFEO (1.2:3 MOL)'},
#  {'formulation': [{'compound_id': 'MTHF',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133b5')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.7,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')},
#    {'compound_id': 'TTE',
#     'quantity': 0.5,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133a4')}],
#   'description': '1.7 M LIFSI METHF-TTE (1:1 VOL)'},
#  {'formulation': [], 'description': 'LIFSI-1DME-3TTE'},
#  {'formulation': [], 'description': 'LIFSI-1.2DME-3TFEO'},
#  {'formulation': [{'compound_id': 'F4DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133cc')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1.2 M LIFSI F4DEE'},
#  {'formulation': [{'compound_id': 'F5DEE',
#     'quantity': 1.0,
#     'quantity_type': 'volume_percent',
#     'compound': ObjectId('68be2a10c1da24c9aac133cd')},
#    {'compound_id': 'LiFSI',
#     'quantity': 1.2,
#     'quantity_type': 'moles',
#     'compound': ObjectId('68be2a10c1da24c9aac133cf')}],
#   'description': '1.2 M LIFSI F5DEE'}]

# %%
import inspect
inspect.iscoroutinefunction(insert_preparation_ML_formulations)
# Out:
# True
